# %%
# importing necessary modules for data cleaning and preprocessing

import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime

# %%
# converting data in dataframe

df = pd.read_csv('E:\sales_analysis\datasets\online_retail.csv')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\3562321399.py:3: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('E:\sales_analysis\datasets\online_retail.csv')

# %%
# viewing the random rows of the dataframe
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#     InvoiceDate  Price  Customer ID         Country
# 0  12/1/09 7:45   6.95      13085.0  United Kingdom
# 1  12/1/09 7:45   6.75      13085.0  United Kingdom
# 2  12/1/09 7:45   6.75      13085.0  United Kingdom
# 3  12/1/09 7:45   2.10      13085.0  United Kingdom
# 4  12/1/09 7:45   1.25      13085.0  United Kingdom

# %% [markdown]
# Observation :
#
# -> There are few data points that shows cancellation or return of any certain product whose invoice code starts with C, but in few datapoints, the customerID is missing! So we can not use those data points for customer segmentation however we can still use it for stock suggestion as how much return/cancellation rate does a product have!
#
# -> Description of few products are missing which definitely won't effect the ml model as we don't neccesarily need the description, but we can fix it by checking if there is any other sale with same product code and filling the gap! (by finding the mode of 'Description' of same stock code)
#
# -> Few invoices start with some other letter like 'A' for adjustment which doesn't tell me alot.
#
# -> Few products were sold at negative quantity but their invoices dont start with 'C' which might mean damages or gifts or ebay sales or miscelleneous, which means they are outlliers.

# %% [markdown]
# <h4>Invoice</h4>
# <ul>
# <li> Starts with 'C' : means cacellation or return of a particular product
# <li> Starts with 'A' : means bad debt adjustments
# </ul>

# %%
# Number of unique products

unique_products = df["StockCode"].unique()

print("TOTAL UNIQUE PRODUCTS :", len(unique_products))
# Out:
# TOTAL UNIQUE PRODUCTS : 4632

# %% [markdown]
# Objective : filling Description of products with missing description
#
# Method :
#
# -> finding the data point with missing description
#
# -> fetching its stockcode
#
# -> fetching description of all the datapoints with same stock code
#
# -> finding mode of set of all descriptions with required stock code
#
# -> filling the mode value at the missing place
#
# -> if there is no other datapoint with same stock id, then remove it!
#
# -> in the end check if there is any datapoint missing
#
# -> repeat the whole process until there is no NaN in Description
#
# column name for stock code is "StockCode" and description is "Description"

# %%
def fill_missing_descriptions(df):
    
    # Create a copy to avoid modifying the original dataframe
    df_copy = df.copy()
    
    print(f"Starting with {len(df_copy)} total records")
    print(f"Missing descriptions: {df_copy['Description'].isna().sum()}")
    
    iteration = 0
    
    # Repeat until no missing descriptions remain
    while df_copy['Description'].isna().any():
        iteration += 1
        print(f"\n--- Iteration {iteration} ---")
        
        # Find datapoints with missing descriptions
        missing_mask = df_copy['Description'].isna()
        missing_stockcodes = df_copy[missing_mask]['StockCode'].unique()
        
        print(f"Stock codes with missing descriptions: {len(missing_stockcodes)}")
        
        # Track which rows to remove (no other datapoints with same stock code)
        rows_to_remove = []
        filled_count = 0
        
        for stockcode in missing_stockcodes:
            # Get all descriptions for this stock code (excluding NaN)
            stockcode_descriptions = df_copy[
                (df_copy['StockCode'] == stockcode) & 
                (df_copy['Description'].notna())
            ]['Description']
            
            if len(stockcode_descriptions) == 0:
                # No other datapoints with this stock code - mark for removal
                rows_to_remove.extend(
                    df_copy[
                        (df_copy['StockCode'] == stockcode) & 
                        (df_copy['Description'].isna())
                    ].index.tolist()
                )
                print(f"  Stock code {stockcode}: No other descriptions found - marking for removal")
            
            else:
                # Find mode (most frequent description) for this stock code
                try:
                    # Count occurrences of each description
                    description_counts = stockcode_descriptions.value_counts()
                    
                    # Get the most frequent description (mode)
                    mode_description = description_counts.index[0]
                    mode_count = description_counts.iloc[0]
                    
                    # Fill missing descriptions with the mode
                    mask = (df_copy['StockCode'] == stockcode) & (df_copy['Description'].isna())
                    df_copy.loc[mask, 'Description'] = mode_description
                    
                    filled_this_stockcode = mask.sum()
                    filled_count += filled_this_stockcode
                    
                    print(f"  Stock code {stockcode}: Filled {filled_this_stockcode} missing descriptions with '{mode_description}' (appeared {mode_count} times)")
                
                except Exception as e:
                    print(f"  Error processing stock code {stockcode}: {e}")
        
        # Remove rows that can't be filled
        if rows_to_remove:
            df_copy = df_copy.drop(rows_to_remove)
            print(f"  Removed {len(rows_to_remove)} rows with no fillable descriptions")
        
        print(f"  Filled {filled_count} descriptions in this iteration")
        print(f"  Remaining missing descriptions: {df_copy['Description'].isna().sum()}")
        print(f"  Total records remaining: {len(df_copy)}")
        
        # Safety check to prevent infinite loops
        if iteration > 100:
            print("\nWarning: Maximum iterations reached. Breaking to prevent infinite loop.")
            break
    
    print(f"\n=== Final Results ===")
    print(f"Total iterations: {iteration}")
    print(f"Final record count: {len(df_copy)}")
    print(f"Remaining missing descriptions: {df_copy['Description'].isna().sum()}")
    print(f"Records removed: {len(df) - len(df_copy)}")
    
    return df_copy

def analyze_descriptions_by_stockcode(df):
    """
    Analyze the distribution of descriptions by stock code to understand the data.
    
    Parameters:
    df (pandas.DataFrame): DataFrame with 'StockCode' and 'Description' columns
    """
    print("=== Description Analysis by Stock Code ===")
    
    # Group by stock code and analyze descriptions
    stockcode_analysis = df.groupby('StockCode')['Description'].agg([
        'count',
        'nunique',
        lambda x: x.isna().sum()
    ]).rename(columns={'<lambda_0>': 'missing_count'})
    
    stockcode_analysis['non_missing_count'] = stockcode_analysis['count'] - stockcode_analysis['missing_count']
    
    print(f"Total unique stock codes: {len(stockcode_analysis)}")
    print(f"Stock codes with all missing descriptions: {(stockcode_analysis['non_missing_count'] == 0).sum()}")
    print(f"Stock codes with some missing descriptions: {(stockcode_analysis['missing_count'] > 0).sum()}")
    print(f"Stock codes with multiple unique descriptions: {(stockcode_analysis['nunique'] > 1).sum()}")
    
    return stockcode_analysis

# Example usage and testing
if __name__ == "__main__":
    
    
    # Load your data
    df = pd.read_csv('E:\sales_analysis\datasets\online_retail.csv')  # or however you load your data
    
    # Optional: Analyze the data first
    analysis = analyze_descriptions_by_stockcode(df)
    
    # Fill missing descriptions
    df_cleaned = fill_missing_descriptions(df)
    
    # Save the result
    df_cleaned.to_csv('E:\sales_analysis\datasets\cleaned_data_with_filled_descriptions.csv', index=False)
# Out:
# <>:117: SyntaxWarning: invalid escape sequence '\s'
# <>:126: SyntaxWarning: invalid escape sequence '\s'
# <>:117: SyntaxWarning: invalid escape sequence '\s'
# <>:126: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\3290892807.py:117: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('E:\sales_analysis\datasets\online_retail.csv')  # or however you load your data
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\3290892807.py:126: SyntaxWarning: invalid escape sequence '\s'
#   df_cleaned.to_csv('E:\sales_analysis\datasets\cleaned_data_with_filled_descriptions.csv', index=False)
# === Description Analysis by Stock Code ===
# Total unique stock codes: 4632
# Stock codes with all missing descriptions: 83
# Stock codes with some missing descriptions: 1920
# Stock codes with multiple unique descriptions: 687
# Starting with 525461 total records
# Missing descriptions: 2928
#
# --- Iteration 1 ---
# Stock codes with missing descriptions: 1920
#   Stock code 21646: No other descriptions found - marking for removal
#   Stock code 20683: Filled 2 missing descriptions with 'RAIN GIRL CHILDS UMBRELLA' (appeared 1 times)
#   Stock code 21350: Filled 3 missing descriptions with 'GINGHAM HEART WREATH' (appeared 46 times)
#   Stock code 84292: Filled 3 missing descriptions with 'ROSE PINK METAL FOLDING CHAIR' (appeared 15 times)
#   Stock code 18010: Filled 2 missing descriptions with 'ASSORTED FRAGRANCE BATH CONFETTI' (appeared 9 times)
#   Stock code 85049G: Filled 2 missing descriptions with 'CHOCOLATE BOX RIBBONS ' (appeared 274 times)
#   Stock code 35751C: Filled 1 missing descriptions with 'PURPLE CURRENT CANDLE RING' (appeared 2 times)
#   Stock code 79323G: Filled 2 missing descriptions with 'GOLD  CHERRY LIGHTS' (appeared 87 times)
#   Stock code 21098: Filled 2 missing descriptions with 'CHRISTMAS TOILET ROLL' (appeared 415 times)
#   Stock code 21166: Filled 3 missing descriptions with 'COOK WITH WINE METAL SIGN ' (appeared 753 times)
#   Stock code 21982: Filled 3 missing descriptions with 'PACK OF 12 SUKI TISSUES ' (appeared 395 times)
#   Stock code 20620: Filled 2 missing descriptions with 'RED SPOTTY PASSPORT COVER' (appeared 14 times)
#   Stock code 85064: Filled 2 missing descriptions with 'CREAM SWEETHEART LETTER RACK' (appeared 268 times)
#   Stock code 84508B: Filled 1 missing descriptions with 'STRIPES DESIGN TEDDY' (appeared 49 times)
#   Stock code 21558: Filled 2 missing descriptions with 'SKULL LUNCH BOX WITH CUTLERY ' (appeared 325 times)
#   Stock code 84347: Filled 4 missing descriptions with 'ROTATING SILVER ANGELS T-LIGHT HLDR' (appeared 369 times)
#   Stock code 21493: Filled 4 missing descriptions with ' VINTAGE DESIGN GIFT TAGS' (appeared 28 times)
#   Stock code 21489: Filled 4 missing descriptions with 'BLUE WHITE SCARF HOT WATER BOTTLE' (appeared 14 times)
#   Stock code 21490: Filled 5 missing descriptions with 'SET OF THREE 50'S GIFT WRAPS ' (appeared 60 times)
#   Stock code 84721: Filled 1 missing descriptions with 'MANHATTAN CANVAS ART PICTURE' (appeared 2 times)
#   Stock code 37446: Filled 6 missing descriptions with 'MINI CAKE STAND WITH HANGING CAKES' (appeared 255 times)
#   Stock code 21133: Filled 2 missing descriptions with 'PAINTED BIRD ASSORTED CHRISTMAS' (appeared 44 times)
#   Stock code 22158: Filled 2 missing descriptions with '3 HEARTS HANGING DECORATION RUSTIC' (appeared 480 times)
#   Stock code 35976B: Filled 2 missing descriptions with 'WHITE SCANDINAVIAN HEART CHRISTMAS' (appeared 2 times)
#   Stock code 35983: No other descriptions found - marking for removal
#   Stock code 72008: Filled 3 missing descriptions with 'FROSTED BOX 9 WHITE T-LIGHT CANDLES' (appeared 223 times)
#   Stock code 15059A: Filled 1 missing descriptions with 'ENGLISH ROSE EDWARDIAN PARASOL' (appeared 4 times)
#   Stock code 84571: No other descriptions found - marking for removal
#   Stock code 20987: Filled 2 missing descriptions with 'GEISHA GIRL CHOPSTICKS SET/5' (appeared 22 times)
#   Stock code 85185F: Filled 3 missing descriptions with 'LION SOCK PUPPET' (appeared 20 times)
#   Stock code 35949: No other descriptions found - marking for removal
#   Stock code 84922: Filled 5 missing descriptions with 'PINK BUTTERFLY WASHBAG' (appeared 11 times)
#   Stock code 20879: Filled 4 missing descriptions with 'TREE OF NOAH FESTIVE SCENTED CANDLE' (appeared 14 times)
#   Stock code 35980C: Filled 3 missing descriptions with 'REDWHITE STRIPE SCANDINAVIAN HEART ' (appeared 33 times)
#   Stock code 22188: Filled 1 missing descriptions with 'BLACK HEART CARD HOLDER' (appeared 398 times)
#   Stock code 22174: Filled 3 missing descriptions with 'PHOTO CUBE' (appeared 273 times)
#   Stock code 17013A: No other descriptions found - marking for removal
#   Stock code 84841: No other descriptions found - marking for removal
#   Stock code 17014C: Filled 1 missing descriptions with 'ORIGAMI LAVENDER INCENSE CONES' (appeared 2 times)
#   Stock code 20940: Filled 2 missing descriptions with 'SET/6 GARDEN GNOME T-LIGHT CANDLES' (appeared 24 times)
#   Stock code 21353: Filled 2 missing descriptions with 'SILVER SLEIGHBELL  WREATH' (appeared 9 times)
#   Stock code 20668: Filled 3 missing descriptions with 'DISCO BALL CHRISTMAS DECORATION' (appeared 177 times)
#   Stock code 72487: Filled 2 missing descriptions with 'ROSES WHITE ROUND CANDLE' (appeared 14 times)
#   Stock code gift_0001_80: Filled 2 missing descriptions with 'Dotcomgiftshop Gift Voucher £80.00' (appeared 2 times)
#   Stock code 72752B: Filled 1 missing descriptions with 'F.FAIRY,CANDLE IN GLASS,LAVENDER' (appeared 2 times)
#   Stock code 72752C: No other descriptions found - marking for removal
#   Stock code 72752A: Filled 1 missing descriptions with 'F.FAIRY,CANDLE IN GLASS,LILY/VALLEY' (appeared 1 times)
#   Stock code 72755C: Filled 2 missing descriptions with 'FLOWER FAIRY OIL BURNER SET ROSE' (appeared 15 times)
#   Stock code 72755B: No other descriptions found - marking for removal
#   Stock code 72752D: No other descriptions found - marking for removal
#   Stock code C2: Filled 2 missing descriptions with 'CARRIAGE' (appeared 136 times)
#   Stock code 21719: Filled 1 missing descriptions with 'LOVELY BONBON STICKER SHEET' (appeared 94 times)
#   Stock code 21724: Filled 1 missing descriptions with 'PANDA AND BUNNIES STICKER SHEET' (appeared 107 times)
#   Stock code 10138: Filled 3 missing descriptions with 'ASSORTED COLOUR JUMBO PEN' (appeared 25 times)
#   Stock code 71477: Filled 4 missing descriptions with 'COLOUR GLASS. STAR T-LIGHT HOLDER' (appeared 578 times)
#   Stock code 22113: Filled 2 missing descriptions with 'GREY HEART HOT WATER BOTTLE' (appeared 505 times)
#   Stock code 22170: Filled 2 missing descriptions with 'PICTURE FRAME WOOD TRIPLE PORTRAIT' (appeared 344 times)
#   Stock code 20870: Filled 2 missing descriptions with 'OPULENT VELVET CANDLE IN BOX' (appeared 9 times)
#   Stock code 16169D: Filled 2 missing descriptions with 'WRAP WINTER FOREST' (appeared 9 times)
#   Stock code 35815B: Filled 1 missing descriptions with 'ACRYLIC JEWEL SNOWFLAKE,BLUE' (appeared 3 times)
#   Stock code 46775B: Filled 1 missing descriptions with 'BERRIES CHUNKY KNITTED THROW ' (appeared 4 times)
#   Stock code 17011C: Filled 1 missing descriptions with 'ORIGAMI LAVENDER INCENSE+FLOWER' (appeared 2 times)
#   Stock code 17011E: Filled 1 missing descriptions with 'ORIGAMI OPIUM SCENT INCENSE+FLOWER' (appeared 1 times)
#   Stock code 17013B: Filled 1 missing descriptions with 'ORIGAMI JASMINE INCENSE IN TUBE' (appeared 3 times)
#   Stock code 22187: Filled 2 missing descriptions with 'GREEN CHRISTMAS TREE CARD HOLDER' (appeared 206 times)
#   Stock code 72756: Filled 4 missing descriptions with 'FAIRY CAKE CANDLES' (appeared 130 times)
#   Stock code 21543: Filled 2 missing descriptions with 'BUTTERFLY WATER TRANSFER TATTOOS ' (appeared 24 times)
#   Stock code 72267: Filled 1 missing descriptions with 'PREMIUM CHURCH CANDLE' (appeared 48 times)
#   Stock code 47504J: Filled 2 missing descriptions with 'ENGLISH ROSE SET/3 GARDEN TOOLS' (appeared 6 times)
#   Stock code 46000M: Filled 3 missing descriptions with 'POLYESTER FILLER PAD 45x45cm' (appeared 228 times)
#   Stock code 84029G: Filled 1 missing descriptions with 'KNITTED UNION FLAG HOT WATER BOTTLE' (appeared 649 times)
#   Stock code 16161C: Filled 3 missing descriptions with 'WRAP SPEED DEMONS ' (appeared 2 times)
#   Stock code 21479: Filled 4 missing descriptions with 'WHITE SKULL HOT WATER BOTTLE ' (appeared 531 times)
#   Stock code 47503F: Filled 3 missing descriptions with 'ASS FLORAL PRINT TORCH' (appeared 13 times)
#   Stock code 72045D: Filled 3 missing descriptions with 'ROSES ON BLUE TEACUP CANDLE ' (appeared 7 times)
#   Stock code 84249D: Filled 3 missing descriptions with 'FAIRY CAKE GREETINGS CARD' (appeared 67 times)
#   Stock code 17164B: Filled 2 missing descriptions with 'ASS COL SMALL SAND GECKO P'WEIGHT' (appeared 83 times)
#   Stock code 84247H: Filled 2 missing descriptions with 'PACK/12 DECOUPAGE CARD' (appeared 21 times)
#   Stock code 84199: Filled 2 missing descriptions with 'GLOW IN DARK DOLPHINS' (appeared 44 times)
#   Stock code 35751A: No other descriptions found - marking for removal
#   Stock code 37485: Filled 2 missing descriptions with 'ENGLISH ROSE TEA SET IN GIFT BOX' (appeared 16 times)
#   Stock code 84814B: Filled 1 missing descriptions with 'RHOMBUS CRYSTAL PERFUME BOTTLE' (appeared 3 times)
#   Stock code 20736: Filled 2 missing descriptions with 'PINK MINI TAPE MEASURE ' (appeared 20 times)
#   Stock code 22197: Filled 4 missing descriptions with 'SMALL POPCORN HOLDER' (appeared 951 times)
#   Stock code 20952: Filled 3 missing descriptions with 'PORCELAIN CHERUB BELL SMALL' (appeared 27 times)
#   Stock code 72724: Filled 1 missing descriptions with 'SET/6 CHRISTMAS ICICLE T-LIGHTS' (appeared 11 times)
#   Stock code 71263G: No other descriptions found - marking for removal
#   Stock code 21560: Filled 2 missing descriptions with 'TOADSTOOL  LUNCHBOX WITH CUTLERY' (appeared 4 times)
#   Stock code 17164D: Filled 2 missing descriptions with 'ASS COL SMALL SAND FROG P'WEIGHT' (appeared 34 times)
#   Stock code 35603B: Filled 2 missing descriptions with 'S/16 BLACK SHINY/MAT BAUBLES' (appeared 3 times)
#   Stock code 35999: Filled 1 missing descriptions with 'S/6 SCANDINAVIAN HEART T-LIGHT' (appeared 1 times)
#   Stock code 79163: Filled 1 missing descriptions with 'BLACK CHAMPAGNE GLASS' (appeared 32 times)
#   Stock code 85230C: Filled 1 missing descriptions with 'ROSE SCENTED VOTIVE CANDLE' (appeared 1 times)
#   Stock code 85230D: Filled 1 missing descriptions with 'VANILLA SCENTED VOTIVE CANDLE' (appeared 1 times)
#   Stock code 72708: Filled 1 missing descriptions with 'SCULPTED ROUND IVORY CANDLE ' (appeared 5 times)
#   Stock code 22144: Filled 3 missing descriptions with 'CHRISTMAS CRAFT LITTLE FRIENDS' (appeared 220 times)
#   Stock code 20691: No other descriptions found - marking for removal
#   Stock code 35051B: Filled 1 missing descriptions with 'PINK BEADED CONE CHRISTMAS' (appeared 2 times)
#   Stock code 20880: No other descriptions found - marking for removal
#   Stock code 20859: No other descriptions found - marking for removal
#   Stock code 22330: Filled 2 missing descriptions with '72 ROUND PINK DOILIES' (appeared 23 times)
#   Stock code 22390: Filled 1 missing descriptions with 'PAPERWEIGHT CHILDHOOD MEMORIES' (appeared 48 times)
#   Stock code 72777: No other descriptions found - marking for removal
#   Stock code 84251C: Filled 2 missing descriptions with 'GREETING CARD, TWO SISTERS.' (appeared 14 times)
#   Stock code 21478: Filled 6 missing descriptions with 'SILVER SKULL HOT WATER BOTTLE ' (appeared 97 times)
#   Stock code 20621: Filled 2 missing descriptions with 'ECONOMY PASSPORT COVER ' (appeared 34 times)
#   Stock code 79069A: No other descriptions found - marking for removal
#   Stock code 85151: Filled 1 missing descriptions with 'WELCOME METAL SIGN' (appeared 8 times)
#   Stock code 22141: Filled 2 missing descriptions with 'CHRISTMAS CRAFT TREE TOP ANGEL' (appeared 165 times)
#   Stock code 44091C: Filled 3 missing descriptions with 'MULTICOLOUR CRUSOE CHECK LAMPSHADE' (appeared 17 times)
#   Stock code 22003: Filled 1 missing descriptions with 'VINTAGE BLUE VACUUM FLASK 0.5L ' (appeared 1 times)
#   Stock code 84247B: No other descriptions found - marking for removal
#   Stock code 84986A: No other descriptions found - marking for removal
#   Stock code 35980A: No other descriptions found - marking for removal
#   Stock code 84940: No other descriptions found - marking for removal
#   Stock code 79053A: No other descriptions found - marking for removal
#   Stock code 72655C: No other descriptions found - marking for removal
#   Stock code 47556: Filled 1 missing descriptions with 'SET/2 SPOTTY + ROSE TEA TOWELS ' (appeared 1 times)
#   Stock code 35977B: No other descriptions found - marking for removal
#   Stock code 85083: Filled 1 missing descriptions with 'KISS REINDEER SCANDINAVIAN STOCKING' (appeared 3 times)
#   Stock code 90002A: Filled 5 missing descriptions with 'FLOWER BURST SILVER RING OPAL' (appeared 17 times)
#   Stock code 20673: Filled 1 missing descriptions with 'STRAWBERRIES PRINT BOWL' (appeared 2 times)
#   Stock code 35975B: No other descriptions found - marking for removal
#   Stock code 20887: Filled 2 missing descriptions with 'BOX OF 6 PEBBLE CANDLES' (appeared 8 times)
#   Stock code 20959: No other descriptions found - marking for removal
#   Stock code 20884: Filled 2 missing descriptions with 'MODERN CHRISTMAS TREE CANDLE ' (appeared 3 times)
#   Stock code 85231D: No other descriptions found - marking for removal
#   Stock code 84921: Filled 2 missing descriptions with 'CREAM AND PINK FLOWERS PONY ' (appeared 13 times)
#   Stock code 85025A: No other descriptions found - marking for removal
#   Stock code 21492: No other descriptions found - marking for removal
#   Stock code 21362: No other descriptions found - marking for removal
#   Stock code 21852: Filled 1 missing descriptions with 'EMPIRE TEDDY' (appeared 2 times)
#   Stock code 35994: No other descriptions found - marking for removal
#   Stock code 47340B: No other descriptions found - marking for removal
#   Stock code 71409B: No other descriptions found - marking for removal
#   Stock code 46307: Filled 2 missing descriptions with 'ROSES BLUE BASE CUSHION COVER ' (appeared 34 times)
#   Stock code 84029D: Filled 3 missing descriptions with 'LEOPARD PRINT HOT WATER BOTTLE' (appeared 15 times)
#   Stock code 84247N: Filled 2 missing descriptions with 'PACK/12 BLUE FOLKART CARDS' (appeared 40 times)
#   Stock code 17129C: Filled 2 missing descriptions with 'SKY BLUE COLOUR GLASS GEMS IN BAG' (appeared 12 times)
#   Stock code 20995: No other descriptions found - marking for removal
#   Stock code 21787: Filled 1 missing descriptions with 'RAIN PONCHO WITH RED SPOTS' (appeared 163 times)
#   Stock code 37451: Filled 2 missing descriptions with 'CERAMIC CAKE TEAPOT WITH CHERRY' (appeared 3 times)
#   Stock code 35001P: Filled 1 missing descriptions with 'HAND OPEN SHAPE PINK' (appeared 3 times)
#   Stock code 21487: No other descriptions found - marking for removal
#   Stock code 78056: Filled 1 missing descriptions with 'CAMOUFLAGE BACKPACK ON WHEELS' (appeared 4 times)
#   Stock code 79065A: Filled 1 missing descriptions with 'TEATIME ROUND CAKE TINS ' (appeared 2 times)
#   Stock code 84558B: No other descriptions found - marking for removal
#   Stock code 37399: Filled 1 missing descriptions with 'ASS RETROSPOOF MUGS,SPORTS' (appeared 6 times)
#   Stock code 21915: Filled 4 missing descriptions with 'RED  HARMONICA IN BOX ' (appeared 413 times)
#   Stock code 16258B: Filled 1 missing descriptions with 'DAISY ERASERS IN BAG' (appeared 17 times)
#   Stock code 21169: Filled 5 missing descriptions with 'YOU'RE CONFUSING ME METAL SIGN ' (appeared 359 times)
#   Stock code 21859: No other descriptions found - marking for removal
#   Stock code 79053B: No other descriptions found - marking for removal
#   Stock code 21029: No other descriptions found - marking for removal
#   Stock code 79340W: Filled 1 missing descriptions with 'WHITE ORCHID FLOWER LIGHTS' (appeared 5 times)
#   Stock code 35821P: Filled 1 missing descriptions with 'JEWELLED DECORATION,PINK' (appeared 2 times)
#   Stock code 20743: No other descriptions found - marking for removal
#   Stock code 21767: Filled 3 missing descriptions with 'FRENCH STYLE WIRE DOOR CABINET ' (appeared 1 times)
#   Stock code 21505: No other descriptions found - marking for removal
#   Stock code 84803B: Filled 3 missing descriptions with 'WHITE ALLIUM  ARTIFICIAL FLOWER' (appeared 8 times)
#   Stock code 21450: Filled 1 missing descriptions with 'DISTRESSED CANDLE STICK WHITE' (appeared 4 times)
#   Stock code 21148: No other descriptions found - marking for removal
#   Stock code 79165: No other descriptions found - marking for removal
#   Stock code 84255A: Filled 2 missing descriptions with 'PINK GLASS COCKTAIL LAMP' (appeared 2 times)
#   Stock code 72483: No other descriptions found - marking for removal
#   Stock code 16195: No other descriptions found - marking for removal
#   Stock code 84811A: No other descriptions found - marking for removal
#   Stock code 47567: Filled 1 missing descriptions with 'ENGLISH ROSE DESIGN KITCHEN APRON' (appeared 2 times)
#   Stock code 71028A: No other descriptions found - marking for removal
#   Stock code 37484: Filled 1 missing descriptions with 'ENGLISH ROSE TEA FOR ONE GIFT BOX' (appeared 1 times)
#   Stock code 37468: Filled 1 missing descriptions with 'HARDMAN MUG 3 ASSORTED' (appeared 1 times)
#   Stock code DCGS0066N: Filled 2 missing descriptions with 'NAVY CUDDLES DOG HOODIE' (appeared 2 times)
#   Stock code 20721: Filled 1 missing descriptions with 'OWLS CHARLOTTE BAG' (appeared 1 times)
#   Stock code 20737: Filled 1 missing descriptions with 'RED MINI TAPE MEASURE ' (appeared 1 times)
#   Stock code 84899A: No other descriptions found - marking for removal
#   Stock code 84928: No other descriptions found - marking for removal
#   Stock code 84972L: Filled 3 missing descriptions with 'GIANT PINK HEART MEMO HOLDER' (appeared 46 times)
#   Stock code 47347A: No other descriptions found - marking for removal
#   Stock code 72785A: Filled 4 missing descriptions with 'S/4 CONTEMPORY PINK ROSEBUD CANDLES' (appeared 4 times)
#   Stock code 72803B: Filled 6 missing descriptions with 'OCEAN SCENT CANDLE JEWELLED DRAWER' (appeared 42 times)
#   Stock code 79309A: No other descriptions found - marking for removal
#   Stock code 85098A: No other descriptions found - marking for removal
#   Stock code 48172: No other descriptions found - marking for removal
#   Stock code 84927C: No other descriptions found - marking for removal
#   Stock code 84945: Filled 2 missing descriptions with 'MULTI COLOUR SILVER T-LIGHT HOLDER' (appeared 350 times)
#   Stock code 72778: No other descriptions found - marking for removal
#   Stock code 84757: Filled 2 missing descriptions with 'ENCHANTED GARDEN WROUGHT IRON TABLE' (appeared 4 times)
#   Stock code TEST002: Filled 1 missing descriptions with 'This is a test product.' (appeared 1 times)
#   Stock code 35945: Filled 1 missing descriptions with 'GOLD CHRISTMAS STOCKING DECORATION' (appeared 1 times)
#   Stock code 35598C: Filled 1 missing descriptions with 'WHITE CHRISTMAS TREE 60CM' (appeared 1 times)
#   Stock code 90121A: No other descriptions found - marking for removal
#   Stock code 85018C: Filled 4 missing descriptions with 'S/6 PAPER BOXES CURIOUS IMAGES ' (appeared 4 times)
#   Stock code 85184A: No other descriptions found - marking for removal
#   Stock code 37492A: Filled 1 missing descriptions with 'YELLOW RED FLOWER PIGGY BANK' (appeared 12 times)
#   Stock code 84705B: Filled 1 missing descriptions with 'FAIRY CAKES PHOTO FRAME' (appeared 3 times)
#   Stock code 37492C: Filled 2 missing descriptions with 'GREEN BLUE FLOWER PIGGY BANK' (appeared 26 times)
#   Stock code 35004S: Filled 2 missing descriptions with 'SET OF 3 SILVER FLYING DUCKS' (appeared 31 times)
#   Stock code 37452B: No other descriptions found - marking for removal
#   Stock code 37452A: No other descriptions found - marking for removal
#   Stock code 21231: Filled 2 missing descriptions with 'SWEETHEART CERAMIC TRINKET BOX' (appeared 1096 times)
#   Stock code 40046C: Filled 2 missing descriptions with 'PINK BUTTERFLY PAPER LAMPSHADE' (appeared 3 times)
#   Stock code 47009: No other descriptions found - marking for removal
#   Stock code 84753A: Filled 2 missing descriptions with 'PINK EAU DE COLOGNE BOTTLE' (appeared 24 times)
#   Stock code 37509: Filled 5 missing descriptions with 'NEW ENGLAND MUG W GIFT BOX' (appeared 16 times)
#   Stock code 20911: No other descriptions found - marking for removal
#   Stock code 35990: No other descriptions found - marking for removal
#   Stock code 84671A: No other descriptions found - marking for removal
#   Stock code 90004A: Filled 1 missing descriptions with 'JADE GREEN PAIR ENAMEL HAIR SLIDES' (appeared 1 times)
#   Stock code 90121B: Filled 2 missing descriptions with 'VINTAGE ROSE BEAD BRACELET BLUE' (appeared 10 times)
#   Stock code 20973: Filled 1 missing descriptions with '12 PENCIL SMALL TUBE WOODLAND' (appeared 348 times)
#   Stock code 22213: No other descriptions found - marking for removal
#   Stock code 84855: Filled 3 missing descriptions with 'BLOKEY SILVER TOOL SET' (appeared 16 times)
#   Stock code 62097A: Filled 2 missing descriptions with 'PINK STRIPES SHOULDER BAG' (appeared 3 times)
#   Stock code 84877C: No other descriptions found - marking for removal
#   Stock code 85232C: Filled 2 missing descriptions with 'RUSSIAN FOLKART STACKING TINS' (appeared 1 times)
#   Stock code 90082C: Filled 2 missing descriptions with 'DIAMANTE BOW BROOCH WHITE COLOUR' (appeared 3 times)
#   Stock code 90091: Filled 3 missing descriptions with 'CRYSTAL DRAGONFLY PHONE CHARM' (appeared 2 times)
#   Stock code 72754D: Filled 2 missing descriptions with 'F FAIRY POTPOURRI CUSHIONS SUMMER' (appeared 1 times)
#   Stock code 72740A: Filled 1 missing descriptions with 'LARGE STRAWBERRY CHOCOLATE CANDLE' (appeared 12 times)
#   Stock code 85166A: Filled 2 missing descriptions with 'WHITE METAL BAROQUE PHOTO FRAME' (appeared 13 times)
#   Stock code 21981: Filled 3 missing descriptions with 'PACK OF 12 WOODLAND TISSUES ' (appeared 317 times)
#   Stock code 17129D: Filled 4 missing descriptions with 'CLEAR COLOUR GLASS GEMS IN BAG' (appeared 39 times)
#   Stock code 84718: No other descriptions found - marking for removal
#   Stock code 20753: Filled 2 missing descriptions with 'RETRO PINK SPOT WASHING UP GLOVES' (appeared 57 times)
#   Stock code 21322: Filled 2 missing descriptions with 'GLASS SPHERE CANDLE STAND LARGE ' (appeared 14 times)
#   Stock code 21649: Filled 1 missing descriptions with 'ASSORTED TUTTI FRUTTI PHOTO FRAME' (appeared 31 times)
#   Stock code 21779: Filled 2 missing descriptions with 'MA CAMPAGNE MINI WOODEN CHEST' (appeared 25 times)
#   Stock code 82484: Filled 1 missing descriptions with 'WOOD BLACK BOARD ANT WHITE FINISH' (appeared 536 times)
#   Stock code 84671B: Filled 1 missing descriptions with 'CROCHET BEAR WITH BLUE STRIPES' (appeared 35 times)
#   Stock code 20913: Filled 3 missing descriptions with 'SET/5 BLUE SPOTTY LID GLASS BOWLS' (appeared 43 times)
#   Stock code 21502: No other descriptions found - marking for removal
#   Stock code 21914: Filled 4 missing descriptions with 'BLUE HARMONICA IN BOX ' (appeared 400 times)
#   Stock code 21118: Filled 1 missing descriptions with 'SHOPPING BAG DOORSTOP' (appeared 7 times)
#   Stock code 16169G: Filled 1 missing descriptions with 'WRAP ROMANTIC DECOUPAGE' (appeared 1 times)
#   Stock code 20968: Filled 2 missing descriptions with 'GREEN FLORAL FELTCRAFT SHOULDER BAG' (appeared 20 times)
#   Stock code 21430: Filled 1 missing descriptions with 'SET/3 RED GINGHAM ROSE STORAGE BOX' (appeared 370 times)
#   Stock code 20688: Filled 2 missing descriptions with 'BEAUTY SPEED EXPRESSO CUPS' (appeared 11 times)
#   Stock code 21553: Filled 3 missing descriptions with 'CERAMIC BIRDHOUSE FINCH BLUE  LARGE' (appeared 42 times)
#   Stock code 21554: Filled 2 missing descriptions with 'CERAMIC BIRDHOUSE RED ROOF LARGE' (appeared 25 times)
#   Stock code 21551: Filled 3 missing descriptions with 'CERAMIC BIRDHOUSE BUTTERFLY LARGE' (appeared 22 times)
#   Stock code 21552: Filled 3 missing descriptions with 'CERAMIC BIRDHOUSE BLACK ROSE  LARGE' (appeared 39 times)
#   Stock code 21893: Filled 3 missing descriptions with 'POTTING SHED SEED TIN' (appeared 20 times)
#   Stock code 85128: Filled 1 missing descriptions with 'PLANTPOT SINGLE HOOK PISTACHIO' (appeared 4 times)
#   Stock code 84925A: Filled 3 missing descriptions with 'WAKE UP COCKEREL WALL THERMOMETER' (appeared 17 times)
#   Stock code 84925E: Filled 1 missing descriptions with 'FLOWERS WALL THERMOMETER' (appeared 3 times)
#   Stock code 84925D: Filled 3 missing descriptions with 'LA PALMIERA WALL THERMOMETER' (appeared 18 times)
#   Stock code 84838: Filled 1 missing descriptions with 'ANT WHITE HIGH RISE BIRD BOX' (appeared 4 times)
#   Stock code 84767: Filled 2 missing descriptions with 'ZINC POLICE BOX LANTERN' (appeared 6 times)
#   Stock code 84830: Filled 3 missing descriptions with 'LARGE ENGLISH ARBORETUM' (appeared 8 times)
#   Stock code 21309: Filled 2 missing descriptions with 'LOUVRE CHALKBOARD' (appeared 6 times)
#   Stock code 21340: Filled 6 missing descriptions with 'CLASSIC METAL BIRDCAGE PLANT HOLDER' (appeared 148 times)
#   Stock code 85120: No other descriptions found - marking for removal
#   Stock code 37345: Filled 1 missing descriptions with 'ASSTD HEARTS DESIGN MUGS' (appeared 9 times)
#   Stock code 21364: Filled 1 missing descriptions with 'PEACE SMALL WOOD LETTERS' (appeared 150 times)
#   Stock code 20714: Filled 1 missing descriptions with 'POSY SHOPPER BAG' (appeared 28 times)
#   Stock code 84029C: Filled 1 missing descriptions with 'BROWN FURRY HOT WATER BOTTLE' (appeared 48 times)
#   Stock code 84997A: Filled 2 missing descriptions with 'GREEN 3 PIECE MINI DOTS CUTLERY SET' (appeared 244 times)
#   Stock code 84997D: Filled 3 missing descriptions with 'PINK 3 PIECE MINI DOTS CUTLERY SET' (appeared 465 times)
#   Stock code 21477: Filled 3 missing descriptions with 'STRING OF 20 ROSE LIGHTS' (appeared 53 times)
#   Stock code 84572: Filled 1 missing descriptions with '6 HOOK JEWEL STAND LILAC DRESS' (appeared 1 times)
#   Stock code gift_0001_30: Filled 4 missing descriptions with 'Dotcomgiftshop Gift Voucher £30.00' (appeared 17 times)
#   Stock code 35918B: Filled 3 missing descriptions with 'BLUE FLORIBUNDA EGG WARMER' (appeared 6 times)
#   Stock code 21480: Filled 1 missing descriptions with 'PINK STRIPE HOT WATER BOTTLE' (appeared 60 times)
#   Stock code 79321: Filled 7 missing descriptions with 'CHILLI LIGHTS' (appeared 532 times)
#   Stock code 21252: Filled 2 missing descriptions with 'SET OF MEADOW  FLOWER STICKERS' (appeared 22 times)
#   Stock code 16206B: Filled 1 missing descriptions with 'RED PURSE WITH PINK HEART' (appeared 14 times)
#   Stock code 21731: Filled 1 missing descriptions with 'RED TOADSTOOL LED NIGHT LIGHT' (appeared 753 times)
#   Stock code 72796A: Filled 5 missing descriptions with 'S/3 ENGLISH LAVENDER SQU CANDLE' (appeared 6 times)
#   Stock code 84972M: No other descriptions found - marking for removal
#   Stock code 82553: Filled 3 missing descriptions with 'POP'S GREASY SPOON METAL SIGN' (appeared 42 times)
#   Stock code 82577: No other descriptions found - marking for removal
#   Stock code 71028B: Filled 1 missing descriptions with 'SILVER BLUE EGG T-LIGHT HOLDER' (appeared 13 times)
#   Stock code 72772: Filled 1 missing descriptions with 'SET/4 SCENTED CANDLES IN RAMEKINS' (appeared 9 times)
#   Stock code 17014A: Filled 3 missing descriptions with 'ORIGAMI VANILLA INCENSE CONES' (appeared 9 times)
#   Stock code 72753D: Filled 1 missing descriptions with 'S/3 FLWR FAIRY SUMMER CANDLES' (appeared 11 times)
#   Stock code 20965: No other descriptions found - marking for removal
#   Stock code 84795E: Filled 2 missing descriptions with 'RIO PINK STRIPE HAMMOCK' (appeared 6 times)
#   Stock code 84450A: Filled 2 missing descriptions with 'PINK RABBIT SITTING EASTER' (appeared 6 times)
#   Stock code 16240: No other descriptions found - marking for removal
#   Stock code 84933D: No other descriptions found - marking for removal
#   Stock code 17061: Filled 1 missing descriptions with 'ASSORTED SHAPED STENCIL FOR HENNA' (appeared 1 times)
#   Stock code 16200A: No other descriptions found - marking for removal
#   Stock code 20844: No other descriptions found - marking for removal
#   Stock code 21254: Filled 1 missing descriptions with 'SET OF KITCHEN WALL  STICKERS' (appeared 1 times)
#   Stock code 16044: Filled 3 missing descriptions with 'POP-ART FLUORESCENT PENS' (appeared 3 times)
#   Stock code 16254: Filled 3 missing descriptions with 'TRANSPARENT ACRYLIC TAPE DISPENSER' (appeared 24 times)
#   Stock code 16051: Filled 2 missing descriptions with 'TEATIME PENCIL W STAMP ASST' (appeared 4 times)
#   Stock code 21325: No other descriptions found - marking for removal
#   Stock code 21406: Filled 1 missing descriptions with 'SPOTTY CAT DOORSTOP ' (appeared 1 times)
#   Stock code 20937: No other descriptions found - marking for removal
#   Stock code 21753: No other descriptions found - marking for removal
#   Stock code 35813A: No other descriptions found - marking for removal
#   Stock code 37445A: No other descriptions found - marking for removal
#   Stock code 37445C: No other descriptions found - marking for removal
#   Stock code 37365Y: No other descriptions found - marking for removal
#   Stock code 37445D: No other descriptions found - marking for removal
#   Stock code 37350: No other descriptions found - marking for removal
#   Stock code 37353: No other descriptions found - marking for removal
#   Stock code 82093: Filled 1 missing descriptions with 'HEART SHAPE BUTTON FRAME ' (appeared 28 times)
#   Stock code 37493C: No other descriptions found - marking for removal
#   Stock code 37493B: No other descriptions found - marking for removal
#   Stock code 37493D: No other descriptions found - marking for removal
#   Stock code 84874A: No other descriptions found - marking for removal
#   Stock code 84898E: No other descriptions found - marking for removal
#   Stock code 84933C: Filled 1 missing descriptions with 'LARGE BLUE ORIENTAL FOLDING STOOL' (appeared 6 times)
#   Stock code 79023B: No other descriptions found - marking for removal
#   Stock code 84933B: Filled 1 missing descriptions with 'LARGE PINK PEONY FOLDING STOOL' (appeared 6 times)
#   Stock code 21348: Filled 1 missing descriptions with 'PINK SPOTS CHOCOLATE NESTING BOXES ' (appeared 136 times)
#   Stock code 72768: No other descriptions found - marking for removal
#   Stock code 44266F: No other descriptions found - marking for removal
#   Stock code 47581A: No other descriptions found - marking for removal
#   Stock code 47565: No other descriptions found - marking for removal
#   Stock code 79065B: No other descriptions found - marking for removal
#   Stock code 84494B: No other descriptions found - marking for removal
#   Stock code 84344: No other descriptions found - marking for removal
#   Stock code 85070: Filled 1 missing descriptions with 'ANT WHITE SWEETHEART TABLE W 3 DRAW' (appeared 4 times)
#   Stock code 84575A: Filled 1 missing descriptions with 'PINK DOG CANNISTER' (appeared 9 times)
#   Stock code 84681: No other descriptions found - marking for removal
#   Stock code 84723: Filled 1 missing descriptions with 'CHERRY BLOSSOM CANVAS ART PICTURE' (appeared 8 times)
#   Stock code 84630: Filled 1 missing descriptions with 'FLOWERS AND BIRDS WALL PLAQUE' (appeared 1 times)
#   Stock code 84555A: Filled 2 missing descriptions with 'YELLOW VW BEETLE CERAMIC MONEY BOX' (appeared 17 times)
#   Stock code 18096C: Filled 2 missing descriptions with 'WHITE ROUND PORCELAIN TLIGHT HOLDER' (appeared 23 times)
#   Stock code 72751D: No other descriptions found - marking for removal
#   Stock code 72234: No other descriptions found - marking for removal
#   Stock code 72715: Filled 2 missing descriptions with 'SPHERICAL IVORY CANDLE ' (appeared 13 times)
#   Stock code 72697A: No other descriptions found - marking for removal
#   Stock code 72024HC: No other descriptions found - marking for removal
#   Stock code 72739B: Filled 3 missing descriptions with 'WHITE CHOCOLATE SCENT CANDLE' (appeared 28 times)
#   Stock code 21496: Filled 1 missing descriptions with 'WOODLAND CREATURES  WRAP' (appeared 2 times)
#   Stock code 72739C: Filled 2 missing descriptions with 'DARK CHOCOLATE SCENTCANDLE' (appeared 25 times)
#   Stock code 47562: Filled 2 missing descriptions with 'ENGLISH ROSE IRONING BOARD COVER' (appeared 44 times)
#   Stock code 46000P: Filled 3 missing descriptions with 'POLYESTER FILLER PAD 65CMx65CM' (appeared 46 times)
#   Stock code 72789: Filled 3 missing descriptions with 'BASKET/8 SCENTED LOVE TOKEN CANDLES' (appeared 47 times)
#   Stock code 20791: Filled 2 missing descriptions with 'BLUE TILED SET OF 3 DRAWERS' (appeared 2 times)
#   Stock code 18097B: Filled 3 missing descriptions with 'BLUE TALL PORCELAIN T-LIGHT HOLDER' (appeared 4 times)
#   Stock code 84288B: Filled 3 missing descriptions with 'SET/2 BLUE  NOODLE BASKETS' (appeared 26 times)
#   Stock code 21363: Filled 1 missing descriptions with 'HOME SMALL WOOD LETTERS' (appeared 301 times)
#   Stock code 21409: Filled 1 missing descriptions with 'SPOTTY COCKEREL DOORSTOP' (appeared 1 times)
#   Stock code 84030B: Filled 4 missing descriptions with 'KNITTED POM POM HOT WATER BOTTLE' (appeared 3 times)
#   Stock code 85023A: Filled 2 missing descriptions with 'CRYSTAL LARGE JEWELLED PHOTO FRAME' (appeared 11 times)
#   Stock code 85043: Filled 1 missing descriptions with 'RED HEART CANDY POP LIGHTS' (appeared 4 times)
#   Stock code 85049C: Filled 2 missing descriptions with 'ROMANTIC PINKS RIBBONS ' (appeared 296 times)
#   Stock code 16156A: No other descriptions found - marking for removal
#   Stock code 16169H: No other descriptions found - marking for removal
#   Stock code 21036: Filled 1 missing descriptions with 'SET/2 TEA TOWELS MODERN VINTAGE' (appeared 1 times)
#   Stock code 84706A: Filled 2 missing descriptions with 'ENGLISH ROSE TABLE CLOCK' (appeared 7 times)
#   Stock code 84706C: Filled 1 missing descriptions with 'PINK FLOCK TABLE CLOCK ' (appeared 4 times)
#   Stock code 72753A: Filled 1 missing descriptions with 'S/3 FLWR FAIRY LILLY CANDLES' (appeared 14 times)
#   Stock code 82076: Filled 1 missing descriptions with 'BEECH WOOD PHOTO FRAME ' (appeared 19 times)
#   Stock code 35822B: Filled 1 missing descriptions with 'ACRYLIC BEAD CHAIN, BLUE' (appeared 1 times)
#   Stock code 35822P: Filled 1 missing descriptions with 'ACRYLIC BEAD CHAIN, PINK' (appeared 1 times)
#   Stock code 85167A: Filled 2 missing descriptions with 'WHITE GRAND BAROQUE PHOTO FRAME' (appeared 15 times)
#   Stock code 72750D: Filled 1 missing descriptions with 'F.FAIRY S/3 CANDLE/GLASS' (appeared 11 times)
#   Stock code 84642: No other descriptions found - marking for removal
#   Stock code 84596I: Filled 1 missing descriptions with 'WRAP SWEETS LIGHT PINK SMALL BOWL' (appeared 11 times)
#   Stock code 46775A: Filled 1 missing descriptions with 'BUBBLE GUM CHUNKY KNITTED THROW ' (appeared 33 times)
#   Stock code 47340A: No other descriptions found - marking for removal
#   Stock code 84292B: Filled 2 missing descriptions with 'BLUE COL METAL FOLDING CHAIR' (appeared 6 times)
#   Stock code 72740B: Filled 1 missing descriptions with 'LARGE WHITE CHOCOLATE CANDLE' (appeared 1 times)
#   Stock code 22657: Filled 2 missing descriptions with 'HEN & 2 CHICKS IN BASKET' (appeared 8 times)
#   Stock code gift_0001_50: Filled 2 missing descriptions with 'Dotcomgiftshop Gift Voucher £50.00' (appeared 2 times)
#   Stock code gift_0001_40: Filled 2 missing descriptions with 'Dotcomgiftshop Gift Voucher £40.00' (appeared 2 times)
#   Stock code gift_0001_60: No other descriptions found - marking for removal
#   Stock code gift_0001_70: Filled 2 missing descriptions with 'Dotcomgiftshop Gift Voucher £70.00' (appeared 1 times)
#   Stock code 22016: No other descriptions found - marking for removal
#   Stock code gift_0001_90: No other descriptions found - marking for removal
#   Stock code 22139: Filled 8 missing descriptions with 'RETRO SPOT TEA SET CERAMIC 11 PC ' (appeared 813 times)
#   Stock code 84227: Filled 2 missing descriptions with 'HEN HOUSE W CHICK IN NEST' (appeared 12 times)
#   Stock code 22169: Filled 2 missing descriptions with 'FAMILY ALBUM WHITE PICTURE FRAME' (appeared 364 times)
#   Stock code 17120: No other descriptions found - marking for removal
#   Stock code 84520D: Filled 2 missing descriptions with 'PACK OF 20 FAIRY CAKE PAPER NAPKINS' (appeared 98 times)
#   Stock code 16207A: Filled 2 missing descriptions with 'PINK STRAWBERRY HANDBAG ' (appeared 42 times)
#   Stock code 21967: Filled 2 missing descriptions with 'PACK OF 12 SKULL TISSUES' (appeared 276 times)
#   Stock code 72785B: Filled 1 missing descriptions with 'S/4 CONTEMPORY RED ROSEBUD CANDLES' (appeared 3 times)
#   Stock code 51012C: Filled 2 missing descriptions with 'FEATHER DUSTER, COAL BLACK' (appeared 30 times)
#   Stock code 85193S: No other descriptions found - marking for removal
#   Stock code 21855: No other descriptions found - marking for removal
#   Stock code 16131: No other descriptions found - marking for removal
#   Stock code 20720: No other descriptions found - marking for removal
#   Stock code 18094A: No other descriptions found - marking for removal
#   Stock code 21345: No other descriptions found - marking for removal
#   Stock code 21475: Filled 1 missing descriptions with 'SWEETHEART CREAM STEEL FOLDIN CHAIR' (appeared 2 times)
#   Stock code 21047: No other descriptions found - marking for removal
#   Stock code 21052: No other descriptions found - marking for removal
#   Stock code 21862: No other descriptions found - marking for removal
#   Stock code 21863: No other descriptions found - marking for removal
#   Stock code 72045A: No other descriptions found - marking for removal
#   Stock code 72748: No other descriptions found - marking for removal
#   Stock code 79064C: No other descriptions found - marking for removal
#   Stock code 79302C: No other descriptions found - marking for removal
#   Stock code 79302J: No other descriptions found - marking for removal
#   Stock code 79308B: Filled 2 missing descriptions with 'MOSAIC CANDLE DISH BLUE PURPLE' (appeared 2 times)
#   Stock code 84248E: No other descriptions found - marking for removal
#   Stock code 85057: No other descriptions found - marking for removal
#   Stock code 90097: No other descriptions found - marking for removal
#   Stock code DCGSSGIRL: Filled 1 missing descriptions with 'GIRLS PARTY BAG' (appeared 10 times)
#   Stock code 21835: No other descriptions found - marking for removal
#   Stock code 35818C: Filled 1 missing descriptions with 'ACRYLIC JEWEL ICICLE, CLEAR ' (appeared 1 times)
#   Stock code 44091A: Filled 1 missing descriptions with 'BLUE CRUSOE CHECK LAMPSHADE' (appeared 4 times)
#   Stock code 72755A: No other descriptions found - marking for removal
#   Stock code 82011E: Filled 1 missing descriptions with 'BATHROOM SCALES, FAG BREAK' (appeared 2 times)
#   Stock code 79333: No other descriptions found - marking for removal
#   Stock code 82576: No other descriptions found - marking for removal
#   Stock code 82096: No other descriptions found - marking for removal
#   Stock code 84567: Filled 1 missing descriptions with 'FROSTED GLASS WITH SILVER SURROUND' (appeared 1 times)
#   Stock code DCGS0006: No other descriptions found - marking for removal
#   Stock code DCGS0016: No other descriptions found - marking for removal
#   Stock code DCGS0027: No other descriptions found - marking for removal
#   Stock code DCGS0036: No other descriptions found - marking for removal
#   Stock code DCGS0039: No other descriptions found - marking for removal
#   Stock code 16245B: No other descriptions found - marking for removal
#   Stock code 16222B: No other descriptions found - marking for removal
#   Stock code 17017: No other descriptions found - marking for removal
#   Stock code 18033: No other descriptions found - marking for removal
#   Stock code 21301: No other descriptions found - marking for removal
#   Stock code 21525: Filled 1 missing descriptions with 'BEWARE OF THE CAT DOORMAT' (appeared 3 times)
#   Stock code 21601: No other descriptions found - marking for removal
#   Stock code 35001C: Filled 1 missing descriptions with 'HAND OPEN SHAPE CHROME' (appeared 1 times)
#   Stock code 35232: No other descriptions found - marking for removal
#   Stock code 37504: No other descriptions found - marking for removal
#   Stock code 48173A: Filled 1 missing descriptions with 'DOOR MAT BLUE FLOCK' (appeared 1 times)
#   Stock code 72809: No other descriptions found - marking for removal
#   Stock code 72798B: No other descriptions found - marking for removal
#   Stock code 79057B: No other descriptions found - marking for removal
#   Stock code 84341A: No other descriptions found - marking for removal
#   Stock code 79082C: No other descriptions found - marking for removal
#   Stock code 84585L: No other descriptions found - marking for removal
#   Stock code 84699: No other descriptions found - marking for removal
#   Stock code 84672A: No other descriptions found - marking for removal
#   Stock code 84752B: No other descriptions found - marking for removal
#   Stock code 84845A: Filled 1 missing descriptions with 'HOLLYHOCK SQUARE HANDY TIN' (appeared 1 times)
#   Stock code 85051: No other descriptions found - marking for removal
#   Stock code 85056: No other descriptions found - marking for removal
#   Stock code 85077: Filled 1 missing descriptions with 'KISSING REINDEER TABLE RUNNER' (appeared 1 times)
#   Stock code 85171: Filled 1 missing descriptions with 'S/2 HYACINTH BULB CANDLES' (appeared 1 times)
#   Stock code 16248A: No other descriptions found - marking for removal
#   Stock code 18096B: No other descriptions found - marking for removal
#   Stock code 21227: No other descriptions found - marking for removal
#   Stock code 70037L: No other descriptions found - marking for removal
#   Stock code 35473: No other descriptions found - marking for removal
#   Stock code 16065A: No other descriptions found - marking for removal
#   Stock code 21183: No other descriptions found - marking for removal
#   Stock code 37432: Filled 1 missing descriptions with 'MUG PINK AND PURPLE ARABIC DESIGN' (appeared 1 times)
#   Stock code 84648: Filled 1 missing descriptions with 'NEW BAROQUE WALL MIRROR' (appeared 1 times)
#   Stock code 84705E: No other descriptions found - marking for removal
#   Stock code 84825: No other descriptions found - marking for removal
#   Stock code 84933A: Filled 1 missing descriptions with 'LARGE GREEN PEONY FOLDING STOOL' (appeared 6 times)
#   Stock code 90197A: No other descriptions found - marking for removal
#   Stock code 85069: Filled 1 missing descriptions with 'CREAM SWEETHEART DOUBLE SHELF' (appeared 3 times)
#   Stock code 79315B: No other descriptions found - marking for removal
#   Stock code 79070B: No other descriptions found - marking for removal
#   Stock code 84460A: No other descriptions found - marking for removal
#   Stock code 84750C: No other descriptions found - marking for removal
#   Stock code 84810C: No other descriptions found - marking for removal
#   Stock code 84938: No other descriptions found - marking for removal
#   Stock code 85105: No other descriptions found - marking for removal
#   Stock code DCGS0060: No other descriptions found - marking for removal
#   Stock code 16192: Filled 1 missing descriptions with 'PINK BALLET OPENING CUBE BOX ' (appeared 1 times)
#   Stock code 21170: No other descriptions found - marking for removal
#   Stock code 35442: No other descriptions found - marking for removal
#   Stock code 35960: No other descriptions found - marking for removal
#   Stock code 37438: Filled 1 missing descriptions with 'FUNKY FLOWER COFFEE POT' (appeared 2 times)
#   Stock code 37483: Filled 2 missing descriptions with 'ENGLISH ROSE MUG IN GIFT BOX' (appeared 14 times)
#   Stock code 72348B: No other descriptions found - marking for removal
#   Stock code 72771C: Filled 1 missing descriptions with 'BLACK FLOCK GOLD CANDLE' (appeared 6 times)
#   Stock code 84395: No other descriptions found - marking for removal
#   Stock code DCGS0056: No other descriptions found - marking for removal
#   Stock code 85148: No other descriptions found - marking for removal
#   Stock code 16155H: No other descriptions found - marking for removal
#   Stock code 21104: No other descriptions found - marking for removal
#   Stock code 37490C: No other descriptions found - marking for removal
#   Stock code 45008L: No other descriptions found - marking for removal
#   Stock code 84897A: No other descriptions found - marking for removal
#   Stock code 72620A: No other descriptions found - marking for removal
#   Stock code 75132: No other descriptions found - marking for removal
#   Stock code 84626: Filled 1 missing descriptions with 'CANDY STRIPE ROSE QUILT' (appeared 1 times)
#   Stock code 10109: Filled 1 missing descriptions with 'BENDY COLOUR PENCILS' (appeared 1 times)
#   Stock code 44276: No other descriptions found - marking for removal
#   Stock code 21909: No other descriptions found - marking for removal
#   Stock code 47554: Filled 1 missing descriptions with 'S/3 COLOURS FLOCK TEA TOWELS' (appeared 1 times)
#   Stock code 72796C: Filled 1 missing descriptions with 'S/3 ROSE GARDEN SCENT SQU CANDLE' (appeared 1 times)
#   Stock code 82039C: No other descriptions found - marking for removal
#   Stock code 79301: Filled 1 missing descriptions with 'FEATHER HEART LIGHTS' (appeared 5 times)
#   Stock code 79303A: Filled 2 missing descriptions with 'WHITE ROHMBIC BLOCK TABLE LAMP' (appeared 1 times)
#   Stock code 84798C: Filled 1 missing descriptions with 'WHITE FOXGLOVE ARTIIFCIAL FLOWER' (appeared 3 times)
#   Stock code 84857B: No other descriptions found - marking for removal
#   Stock code 84873B: No other descriptions found - marking for removal
#   Stock code 21081: Filled 1 missing descriptions with 'SET/20 POSIES PAPER NAPKINS' (appeared 4 times)
#   Stock code 37326: Filled 2 missing descriptions with 'FAIRY DESIGN MUGS' (appeared 3 times)
#   Stock code 21685: Filled 1 missing descriptions with 'MEDINA STAMPED METAL TRAY ' (appeared 3 times)
#   Stock code 21176: No other descriptions found - marking for removal
#   Stock code 21053: Filled 1 missing descriptions with 'ZINC HEART HANGER WITH HOOKS' (appeared 1 times)
#   Stock code 35970: Filled 6 missing descriptions with 'ZINC FOLKART SLEIGH BELLS' (appeared 253 times)
#   Stock code 35926: No other descriptions found - marking for removal
#   Stock code 79003B: No other descriptions found - marking for removal
#   Stock code 84371: Filled 1 missing descriptions with 'BIG PINK POODLE' (appeared 6 times)
#   Stock code 84904: No other descriptions found - marking for removal
#   Stock code 21236: No other descriptions found - marking for removal
#   Stock code 20955: No other descriptions found - marking for removal
#   Stock code 72140D: No other descriptions found - marking for removal
#   Stock code 90060C: Filled 3 missing descriptions with 'FIRE POLISHED GLASS NECKL SILVER' (appeared 3 times)
#   Stock code 84425A: Filled 3 missing descriptions with 'WHITE GLASS TV TRIPLE FRAME' (appeared 9 times)
#   Stock code 84427B: Filled 4 missing descriptions with 'BLACK GLASS TV DOUBLE P/FRAME 15X10' (appeared 5 times)
#   Stock code 72805: Filled 2 missing descriptions with 'VANILLA CANDLE IN EMBOSSED ZINC POT' (appeared 3 times)
#   Stock code 15060A: No other descriptions found - marking for removal
#   Stock code 21382: Filled 1 missing descriptions with 'SET/4 SPRING FLOWER DECORATION' (appeared 26 times)
#   Stock code 21510: No other descriptions found - marking for removal
#   Stock code 21772: Filled 1 missing descriptions with 'VINTAGE METAL CAKE STAND CREAM ' (appeared 1 times)
#   Stock code 47559: No other descriptions found - marking for removal
#   Stock code 72671B: No other descriptions found - marking for removal
#   Stock code 85207B: No other descriptions found - marking for removal
#   Stock code 16132: No other descriptions found - marking for removal
# ...
#   Stock code 85017D: No other descriptions found - marking for removal
#   Stock code 21535: Filled 2 missing descriptions with 'RED RETROSPOT SMALL MILK JUG' (appeared 510 times)
#   Stock code 35832: Filled 2 missing descriptions with 'WOOLLY HAT SOCK GLOVE ADVENT STRING' (appeared 194 times)
#   Stock code 20865: Filled 1 missing descriptions with 'PATCHWORK PENCIL CASE BUTTERFLY ' (appeared 35 times)
#   Stock code 20864: Filled 1 missing descriptions with 'DENIM PATCH PENCIL CASE BUTTERFLY' (appeared 31 times)
#   Stock code 21541: Filled 1 missing descriptions with 'DINOSAURS WATER TRANSFER TATTOOS ' (appeared 206 times)
#   Stock code 85232A: Filled 1 missing descriptions with 'SET/3 POLKA DOT STACKING TINS' (appeared 108 times)
#   Stock code 84762B: Filled 1 missing descriptions with 'PINK PICNIC BARBECUE BUCKET' (appeared 48 times)
#   Stock code 85224: Filled 1 missing descriptions with 'ASSORTED COLOUR SILK GLASSES CASE' (appeared 66 times)
#   Stock code 21153: Filled 1 missing descriptions with 'RED SPOTTY TABLECLOTH ' (appeared 141 times)
#   Stock code 22172: Filled 1 missing descriptions with 'METAL SHELF WITH RAIL ' (appeared 190 times)
#   Stock code 85126: Filled 2 missing descriptions with 'LARGE ROUND CUTGLASS CANDLESTICK' (appeared 38 times)
#   Stock code 22461: Filled 1 missing descriptions with 'SAVOY ART DECO CLOCK' (appeared 118 times)
#   Stock code 85132B: Filled 1 missing descriptions with 'CHARLIE AND LOLA TABLE TINS' (appeared 52 times)
#   Stock code 35001G: Filled 1 missing descriptions with 'HAND OPEN SHAPE GOLD' (appeared 78 times)
#   Stock code 71279: Filled 1 missing descriptions with 'PINK GLASS CANDLEHOLDER' (appeared 50 times)
#   Stock code 84750B: Filled 1 missing descriptions with 'BLACK SMALL GLASS CAKE STAND' (appeared 69 times)
#   Stock code 85135B: Filled 1 missing descriptions with 'BLUE DRAGONFLY HELICOPTER' (appeared 89 times)
#   Stock code 84192: Filled 1 missing descriptions with 'ASSORTED COLOUR METAL CAT ' (appeared 17 times)
#   Stock code 85135C: Filled 1 missing descriptions with 'RED DRAGONFLY HELICOPTER' (appeared 56 times)
#   Stock code 21763: Filled 2 missing descriptions with 'VINTAGE WOODEN BAR STOOL' (appeared 15 times)
#   Stock code 20800: Filled 1 missing descriptions with 'LARGE GLASS SUNDAE DISH CLEAR' (appeared 5 times)
#   Stock code 79071B: Filled 1 missing descriptions with 'ENGLISH ROSE METAL WASTE BIN' (appeared 56 times)
#   Stock code 84664: Filled 1 missing descriptions with 'CHERRY BLOSSOM BATHROOM CABINET' (appeared 53 times)
#   Stock code 22056: Filled 1 missing descriptions with 'CERAMIC PLATE LOVE HEART DESIGN' (appeared 36 times)
#   Stock code 21737: Filled 1 missing descriptions with 'SET 3 WICKER LOG BASKETS' (appeared 166 times)
#   Stock code 84751B: Filled 1 missing descriptions with 'BLACK MEDIUM GLASS CAKE STAND' (appeared 13 times)
#   Stock code 21756: Filled 1 missing descriptions with 'BATH BUILDING BLOCK WORD' (appeared 333 times)
#   Stock code 84839: Filled 1 missing descriptions with 'SWEETHEART KEY CABINET' (appeared 416 times)
#   Stock code 20825: Filled 1 missing descriptions with 'GOLD WINE GLASS' (appeared 8 times)
#   Stock code 84760S: Filled 1 missing descriptions with 'SMALL HANGING GLASS+ZINC LANTERN' (appeared 30 times)
#   Stock code 21444: Filled 1 missing descriptions with 'BLUE CHALET BIRDFEEDER' (appeared 37 times)
#   Stock code 22864: Filled 1 missing descriptions with 'MUG AND COASTER SET RED CIRCLES' (appeared 2 times)
#   Stock code 37343: Filled 1 missing descriptions with 'SPOTS DESIGN MUG W PINK INSIDE' (appeared 75 times)
#   Stock code 47579: Filled 1 missing descriptions with 'TEA TIME BREAKFAST BASKET' (appeared 57 times)
#   Stock code 35471A: Filled 2 missing descriptions with 'SET OF 3 BIRD L.BLUE FEATHER' (appeared 87 times)
#   Stock code 84676: Filled 1 missing descriptions with 'BATH DUCK WATERING CAN' (appeared 120 times)
#   Stock code 20827: Filled 1 missing descriptions with 'GOLD APERITIF GLASS' (appeared 6 times)
#   Stock code 17178: Filled 1 missing descriptions with 'FLAT PALM T-LIGHT HOLDER' (appeared 25 times)
#   Stock code 35833P: Filled 1 missing descriptions with '4 PINK FLOCK CHRISTMAS BALLS' (appeared 46 times)
#   Stock code 47592A: Filled 1 missing descriptions with 'CAROUSEL DES CHILD'S OVERALL' (appeared 74 times)
#   Stock code 85195: Filled 2 missing descriptions with 'HANGING HEART BASKET' (appeared 15 times)
#   Stock code 37423: Filled 1 missing descriptions with 'WHITE WITH BLACK CATS PLATE' (appeared 68 times)
#   Stock code 37424: Filled 1 missing descriptions with 'WHITE WITH BLACK CATS MUG' (appeared 111 times)
#   Stock code 47568: Filled 1 missing descriptions with 'ENGLISH ROSE DESIGN PEG BAG' (appeared 422 times)
#   Stock code 85121C: Filled 1 missing descriptions with 'RETRO LAUNDRY TUB PISTACHIO' (appeared 54 times)
#   Stock code 16015: Filled 1 missing descriptions with 'MEDIUM CHINESE STYLE SCISSOR' (appeared 42 times)
#   Stock code 47503H: Filled 2 missing descriptions with 'ASS FLORAL PRINT SPIRIT LEVEL ' (appeared 27 times)
#   Stock code 35936: Filled 1 missing descriptions with 'CERISE+GOLD CHRISTMAS TREE DEC' (appeared 9 times)
#   Stock code 37464: Filled 2 missing descriptions with 'ROBOT MUG IN DISPLAY BOX' (appeared 82 times)
#   Stock code 84962: Filled 1 missing descriptions with 'SET/3 COLOUR PAINTED KASHMIRI STOOL' (appeared 2 times)
#   Stock code 22126: Filled 1 missing descriptions with 'given away' (appeared 2 times)
#   Stock code 17012A: Filled 1 missing descriptions with 'ORIGAMI VANILLA INCENSE/CANDLE SET ' (appeared 33 times)
#   Stock code 21614: Filled 4 missing descriptions with 'SET OF 12 ROSE BOTANICAL T-LIGHTS' (appeared 192 times)
#   Stock code 84686: Filled 1 missing descriptions with 'BEACH HUT MIRROR' (appeared 71 times)
#   Stock code 20933: Filled 1 missing descriptions with 'YELLOW POT PLANT CANDLE' (appeared 44 times)
#   Stock code 22218: Filled 2 missing descriptions with 'CAKE STAND LACE WHITE' (appeared 278 times)
#   Stock code 22591: Filled 1 missing descriptions with 'CARDHOLDER GINGHAM CHRISTMAS TREE' (appeared 134 times)
#   Stock code 20950: Filled 2 missing descriptions with 'SET/6  ANGEL T-LIGHTS WHITE/GOLD' (appeared 84 times)
#   Stock code 85226C: Filled 2 missing descriptions with 'BLUE PULL BACK RACING CAR' (appeared 85 times)
#   Stock code 85040B: Filled 1 missing descriptions with 'SET/4 BLUE FLOWER CANDLES IN BOWL' (appeared 237 times)
#   Stock code 21491: Filled 1 missing descriptions with 'SET OF THREE VINTAGE GIFT WRAPS' (appeared 260 times)
#   Stock code 82552: Filled 1 missing descriptions with 'WASHROOM METAL SIGN' (appeared 451 times)
#   Stock code 21360: Filled 1 missing descriptions with 'JOY LARGE WOOD LETTERS' (appeared 88 times)
#   Stock code 35591T: Filled 1 missing descriptions with 'TURQUOISE CHRISTMAS TREE ' (appeared 7 times)
#   Stock code 72815: Filled 1 missing descriptions with '3 WICK CHRISTMAS BRIAR CANDLE ' (appeared 72 times)
#   Stock code 22959: Filled 2 missing descriptions with 'WRAP CHRISTMAS VILLAGE' (appeared 146 times)
#   Stock code 21590: Filled 1 missing descriptions with 'KINGS CHOICE CIGAR BOX MATCHES ' (appeared 304 times)
#   Stock code 35932: Filled 1 missing descriptions with 'PINK CHRISTMAS TREE DECORATION' (appeared 10 times)
#   Stock code 35400: Filled 3 missing descriptions with 'WOODEN BOX ADVENT CALENDAR ' (appeared 462 times)
#   Stock code 22470: Filled 2 missing descriptions with 'HEART OF WICKER LARGE' (appeared 1151 times)
#   Stock code 22734: Filled 3 missing descriptions with 'SET OF 6 RIBBONS VINTAGE CHRISTMAS' (appeared 352 times)
#   Stock code 22687: Filled 1 missing descriptions with 'DOORMAT CHRISTMAS VILLAGE' (appeared 97 times)
#   Stock code 72750B: Filled 1 missing descriptions with 'FLOWER FAIRY SET 3 CANDLES LAVENDER' (appeared 33 times)
#   Stock code 85232B: Filled 2 missing descriptions with 'SET/3 RUSSIAN DOLL STACKING TINS' (appeared 393 times)
#   Stock code 21841: Filled 1 missing descriptions with 'BABY MOUSE RED GINGHAM DRESS' (appeared 116 times)
#   Stock code 21826: Filled 1 missing descriptions with 'EIGHT PIECE DINOSAUR SET' (appeared 236 times)
#   Stock code 85226A: Filled 2 missing descriptions with 'WHITE/BLUE PULL BACK RACING CAR' (appeared 159 times)
#   Stock code 21681: Filled 1 missing descriptions with 'GIANT MEDINA STAMPED METAL BOWL ' (appeared 81 times)
#   Stock code 21815: Filled 1 missing descriptions with 'STAR  T-LIGHT HOLDER ' (appeared 69 times)
#   Stock code 20871: Filled 1 missing descriptions with 'OPULENT VELVET SET/3 CANDLES' (appeared 132 times)
#   Stock code 21333: Filled 1 missing descriptions with 'CLASSIC WHITE FRAME' (appeared 223 times)
#   Stock code 84625D: Filled 1 missing descriptions with 'WHITE NEWBAROQUE CANDLESTICK CANDLE' (appeared 57 times)
#   Stock code 22451: Filled 1 missing descriptions with 'SILK PURSE BABUSHKA RED' (appeared 126 times)
#   Stock code 22450: Filled 1 missing descriptions with 'SILK PURSE RUSSIAN DOLL BLUE' (appeared 73 times)
#   Stock code 21186: Filled 2 missing descriptions with 'WHITE DOVE HONEYCOMB PAPER GARLAND' (appeared 380 times)
#   Stock code 21412: Filled 1 missing descriptions with 'VINTAGE GOLD TINSEL REEL' (appeared 77 times)
#   Stock code 20878: Filled 2 missing descriptions with 'SET/9 CHRISTMAS T-LIGHTS SCENTED ' (appeared 89 times)
#   Stock code 35958: Filled 2 missing descriptions with 'FOLKART ZINC STAR CHRISTMAS DEC' (appeared 85 times)
#   Stock code 84908A: Filled 1 missing descriptions with 'PINK 5 PATCH FLOWER CUSHION COVER ' (appeared 38 times)
#   Stock code 21017: Filled 2 missing descriptions with 'RED BIRD HOUSE TREE DECORATION' (appeared 90 times)
#   Stock code 84908B: Filled 1 missing descriptions with 'BLUE 5 PATCH FLOWER CUSHION COVER' (appeared 35 times)
#   Stock code 22962: Filled 1 missing descriptions with 'JAM JAR WITH PINK LID' (appeared 38 times)
#   Stock code 22960: Filled 1 missing descriptions with 'JAM MAKING SET WITH JARS' (appeared 84 times)
#   Stock code 85170A: Filled 2 missing descriptions with 'SET/6 IVORY BIRD T-LIGHT CANDLES' (appeared 87 times)
#   Stock code 22698: Filled 1 missing descriptions with 'PINK REGENCY TEACUP AND SAUCER' (appeared 278 times)
#   Stock code 84952C: Filled 2 missing descriptions with 'MIRROR LOVE BIRD T-LIGHT HOLDER' (appeared 34 times)
#   Stock code 85067: Filled 1 missing descriptions with 'CREAM SWEETHEART WALL CABINET' (appeared 188 times)
#   Stock code 22712: Filled 1 missing descriptions with 'CARD DOLLY GIRL ' (appeared 212 times)
#   Stock code 21421: Filled 1 missing descriptions with 'PORCELAIN ROSE LARGE ' (appeared 97 times)
#   Stock code 21414: Filled 1 missing descriptions with 'SCALLOP SHELL SOAP DISH' (appeared 37 times)
#   Stock code 21653: Filled 1 missing descriptions with 'GLASS ETCHED T-LIGHT HOLDER LARGE' (appeared 122 times)
#   Stock code 21814: Filled 1 missing descriptions with 'HEART T-LIGHT HOLDER ' (appeared 89 times)
#   Stock code 21692: Filled 1 missing descriptions with 'SILVER LATTICE VANILLA CANDLE POT' (appeared 123 times)
#   Stock code 21172: Filled 1 missing descriptions with 'PARTY METAL SIGN ' (appeared 536 times)
#   Stock code 21648: Filled 1 missing descriptions with 'ASSORTED TUTTI FRUTTI SMALL PURSE' (appeared 184 times)
#   Stock code 21161: Filled 1 missing descriptions with 'KEEP OUT BOYS DOOR HANGER ' (appeared 175 times)
#   Stock code 84534B: Filled 2 missing descriptions with 'FAIRY CAKE NOTEBOOK A5 SIZE' (appeared 190 times)
#   Stock code 22162: Filled 1 missing descriptions with 'HEART GARLAND RUSTIC PADDED' (appeared 188 times)
#   Stock code 35965: Filled 1 missing descriptions with 'FOLKART HEART NAPKIN RINGS' (appeared 114 times)
#   Stock code 21836: Filled 1 missing descriptions with 'GINGHAM OVEN GLOVE RED HEART ' (appeared 102 times)
#   Stock code 84562A: Filled 1 missing descriptions with 'PINK/WHITE RIBBED MELAMINE JUG' (appeared 79 times)
#   Stock code 37474: Filled 2 missing descriptions with 'SET/4 2 TONE EGG SHAPE MIXING BOWLS' (appeared 46 times)
#   Stock code 21807: Filled 1 missing descriptions with 'WHITE CHRISTMAS STAR DECORATION' (appeared 158 times)
#   Stock code 21011: Filled 1 missing descriptions with 'GLITTER SNOW PEAR TREE DECORATION' (appeared 131 times)
#   Stock code 18098C: Filled 1 missing descriptions with 'PORCELAIN BUTTERFLY OIL BURNER' (appeared 212 times)
#   Stock code 21696: Filled 1 missing descriptions with 'SMALL SILVER TRELLIS CANDLEPOT' (appeared 84 times)
#   Stock code 84569B: Filled 1 missing descriptions with 'PACK 3 FIRE ENGINE/CAR PATCHES' (appeared 65 times)
#   Stock code 84898F: Filled 1 missing descriptions with 'YELLOW FLOWERS FELT HANDBAG KIT' (appeared 37 times)
#   Stock code 84968B: Filled 1 missing descriptions with 'S/16 VINTAGE IVORY CUTLERY' (appeared 134 times)
#   Stock code 85215: Filled 1 missing descriptions with 'ASSORTED CHEESE FRIDGE MAGNETS' (appeared 53 times)
#   Stock code 84270: Filled 1 missing descriptions with 'ASSTD DESIGN BUBBLE GUM RING' (appeared 485 times)
#   Stock code 21054: Filled 1 missing descriptions with 'NURSE'S BAG SOFT TOY' (appeared 162 times)
#   Stock code 20684: Filled 1 missing descriptions with 'STRAWBERRY DREAM CHILDS UMBRELLA' (appeared 151 times)
#   Stock code 84881: Filled 1 missing descriptions with 'BLUE WIRE SPIRAL CANDLE HOLDER' (appeared 19 times)
#   Stock code 20941: Filled 1 missing descriptions with 'FROG CANDLE' (appeared 110 times)
#   Stock code 21248: Filled 1 missing descriptions with 'DOOR HANGER  MUM + DADS ROOM' (appeared 99 times)
#   Stock code 21349: Filled 1 missing descriptions with 'IVY HEART WREATH' (appeared 171 times)
#   Stock code 22155: Filled 1 missing descriptions with 'STAR DECORATION RUSTIC' (appeared 229 times)
#   Stock code 21488: Filled 2 missing descriptions with 'RED WHITE SCARF  HOT WATER BOTTLE' (appeared 366 times)
#   Stock code 21486: Filled 1 missing descriptions with 'PINK HEART DOTS HOT WATER BOTTLE' (appeared 300 times)
#   Stock code 21595: Filled 1 missing descriptions with 'Dad's Cab Electronic Meter' (appeared 9 times)
#   Stock code 22034: Filled 1 missing descriptions with 'ROBIN CHRISTMAS CARD' (appeared 95 times)
#   Stock code 22114: Filled 1 missing descriptions with 'HOT WATER BOTTLE TEA AND SYMPATHY' (appeared 1050 times)
#   Stock code 22833: Filled 1 missing descriptions with 'HALL CABINET WITH 3 DRAWERS' (appeared 10 times)
#   Stock code 85008: Filled 1 missing descriptions with 'SET OF 3 CONEY ISLAND OVAL BOXES' (appeared 97 times)
#   Stock code 21429: Filled 1 missing descriptions with 'RED GINGHAM ROSE JEWELLERY BOX' (appeared 773 times)
#   Stock code 85167B: Filled 1 missing descriptions with 'BLACK GRAND BAROQUE PHOTO FRAME' (appeared 56 times)
#   Stock code 22454: Filled 1 missing descriptions with 'MEASURING TAPE BABUSHKA RED' (appeared 89 times)
#   Stock code 20966: Filled 1 missing descriptions with 'SANDWICH BATH SPONGE' (appeared 359 times)
#   Stock code 21801: Filled 1 missing descriptions with 'CHRISTMAS TREE DECORATION WITH BELL' (appeared 151 times)
#   Stock code 21743: Filled 1 missing descriptions with 'STAR PORTABLE TABLE LIGHT ' (appeared 156 times)
#   Stock code 37467: Filled 1 missing descriptions with 'PIG MUG IN TWO COLOUR DESIGNS' (appeared 49 times)
#   Stock code 17091A: Filled 1 missing descriptions with 'LAVENDER INCENSE IN TIN' (appeared 95 times)
#   Stock code 90002D: Filled 1 missing descriptions with 'FLOWER BURST SILVER RING CRYSTAL' (appeared 29 times)
#   Stock code 21324: Filled 1 missing descriptions with 'HANGING MEDINA LANTERN SMALL' (appeared 162 times)
#   Stock code 20892: Filled 1 missing descriptions with 'SET/3 TALL GLASS CANDLE HOLDER PINK' (appeared 45 times)
#   Stock code 20956: Filled 1 missing descriptions with 'PORCELAIN T-LIGHT HOLDERS ASSORTED' (appeared 156 times)
#   Removed 365 rows with no fillable descriptions
#   Filled 2563 descriptions in this iteration
#   Remaining missing descriptions: 0
#   Total records remaining: 525096
#
# === Final Results ===
# Total iterations: 1
# Final record count: 525096
# Remaining missing descriptions: 0
# Records removed: 365

# %% [markdown]
# Objective 2 : Creating a new dataset
#
# Columns to keep in new dataset : Invoice, StockCode, Description, Qunatity, InvoiceDate, Price
#
# Method :
#
# -> Create a new dataset named "sales_data.csv"
#
#     designing of Schema of sales_data.csv!
#
#     i have an existing dataset that i have attached, now i want a dataset with monthly and weekly quantity sold and, monthly and weekly total price of each unique stockcode with description of each code (remember that the column "Price" in attached dataset is per unit price then the net price will be quantity * price) , write me python code for that
#
# -> Add all the given columns from

# %%
def create_aggregated_datasets(df, start_date='01/12/2009', end_date='31/12/2010'):
    """
    Create aggregated datasets with monthly and weekly sales data for each product.
    Fills missing periods with zero values for all products.
    
    Parameters:
    df (pandas.DataFrame): Original retail transactions dataset
    start_date (str): Start date in MM/DD/YY format
    end_date (str): End date in MM/DD/YY format
    
    Returns:
    tuple: (monthly_agg, weekly_agg) - Two DataFrames with aggregated data
    """
    
    # Create a copy and ensure proper data types
    df_clean = df.copy()
    
    # Convert InvoiceDate to datetime (handling MM/DD/YY Time format)
    df_clean['InvoiceDate'] = pd.to_datetime(df_clean['InvoiceDate'], format='%m/%d/%y %H:%M')
    
    # Calculate net price (total price per transaction line)
    df_clean['NetPrice'] = df_clean['Quantity'] * df_clean['Price']
    
    # Create period columns for grouping
    df_clean['YearMonth'] = df_clean['InvoiceDate'].dt.to_period('M')
    df_clean['YearWeek'] = df_clean['InvoiceDate'].dt.to_period('W')
    
    print(f"Processing {len(df_clean)} transactions...")
    print(f"Date range: {df_clean['InvoiceDate'].min()} to {df_clean['InvoiceDate'].max()}")
    print(f"Unique products: {df_clean['StockCode'].nunique()}")
    
    # Get unique StockCode-Description mapping
    product_mapping = df_clean.groupby('StockCode')['Description'].agg(
        lambda x: x.mode().iloc[0] if not x.mode().empty else x.iloc[0]
    ).reset_index()
    
    # Create complete date ranges
    start_dt = datetime.strptime(start_date, '%d/%m/%Y')
    end_dt = datetime.strptime(end_date, '%d/%m/%Y')
    
    # Generate all months and weeks in the range
    all_months = pd.period_range(start=start_dt, end=end_dt, freq='M')
    all_weeks = pd.period_range(start=start_dt, end=end_dt, freq='W')
    
    print(f"Complete period range: {start_dt.date()} to {end_dt.date()}")
    print(f"Total months to cover: {len(all_months)}")
    print(f"Total weeks to cover: {len(all_weeks)}")
    
    # === MONTHLY AGGREGATION ===
    print("\nCreating monthly aggregation...")
    
    # Aggregate existing data by month
    monthly_existing = df_clean.groupby(['StockCode', 'YearMonth']).agg({
        'Quantity': 'sum',
        'NetPrice': 'sum'
    }).reset_index()
    
    # Create complete grid: all products × all months
    monthly_grid = pd.MultiIndex.from_product([
        product_mapping['StockCode'].unique(),
        all_months
    ], names=['StockCode', 'YearMonth']).to_frame(index=False)
    
    # Merge with existing data
    monthly_agg = monthly_grid.merge(monthly_existing, on=['StockCode', 'YearMonth'], how='left')
    
    # Fill missing values with 0
    monthly_agg['Quantity'] = monthly_agg['Quantity'].fillna(0)
    monthly_agg['NetPrice'] = monthly_agg['NetPrice'].fillna(0)
    
    # Calculate per unit price (avoid division by zero)
    monthly_agg['Monthly_Per_Unit_Price'] = np.where(
        monthly_agg['Quantity'] > 0,
        monthly_agg['NetPrice'] / monthly_agg['Quantity'],
        0
    )
    
    # Rename columns for clarity
    monthly_agg = monthly_agg.rename(columns={
        'Quantity': 'Monthly_Quantity_Sold',
        'NetPrice': 'Monthly_Total_Price'
    })
    
    # Add Description
    monthly_agg = monthly_agg.merge(product_mapping, on='StockCode', how='left')
    
    # Reorder columns
    monthly_agg = monthly_agg[['StockCode', 'Description', 'YearMonth', 
                              'Monthly_Quantity_Sold', 'Monthly_Total_Price', 'Monthly_Per_Unit_Price']]
    
    print(f"Monthly aggregation created: {len(monthly_agg)} records")
    print(f"Records with zero sales: {(monthly_agg['Monthly_Quantity_Sold'] == 0).sum()}")
    
    # === WEEKLY AGGREGATION ===
    print("\nCreating weekly aggregation...")
    
    # Aggregate existing data by week
    weekly_existing = df_clean.groupby(['StockCode', 'YearWeek']).agg({
        'Quantity': 'sum',
        'NetPrice': 'sum'
    }).reset_index()
    
    # Create complete grid: all products × all weeks
    weekly_grid = pd.MultiIndex.from_product([
        product_mapping['StockCode'].unique(),
        all_weeks
    ], names=['StockCode', 'YearWeek']).to_frame(index=False)
    
    # Merge with existing data
    weekly_agg = weekly_grid.merge(weekly_existing, on=['StockCode', 'YearWeek'], how='left')
    
    # Fill missing values with 0
    weekly_agg['Quantity'] = weekly_agg['Quantity'].fillna(0)
    weekly_agg['NetPrice'] = weekly_agg['NetPrice'].fillna(0)
    
    # Calculate per unit price (avoid division by zero)
    weekly_agg['Weekly_Per_Unit_Price'] = np.where(
        weekly_agg['Quantity'] > 0,
        weekly_agg['NetPrice'] / weekly_agg['Quantity'],
        0
    )
    
    # Rename columns for clarity
    weekly_agg = weekly_agg.rename(columns={
        'Quantity': 'Weekly_Quantity_Sold',
        'NetPrice': 'Weekly_Total_Price'
    })
    
    # Add Description
    weekly_agg = weekly_agg.merge(product_mapping, on='StockCode', how='left')
    
    # Reorder columns
    weekly_agg = weekly_agg[['StockCode', 'Description', 'YearWeek', 
                            'Weekly_Quantity_Sold', 'Weekly_Total_Price', 'Weekly_Per_Unit_Price']]
    
    print(f"Weekly aggregation created: {len(weekly_agg)} records")
    print(f"Records with zero sales: {(weekly_agg['Weekly_Quantity_Sold'] == 0).sum()}")
    
    return monthly_agg, weekly_agg

def analyze_aggregated_data(monthly_agg, weekly_agg):
    """
    Provide insights about the aggregated datasets.
    """
    
    print("\n=== AGGREGATION ANALYSIS ===")
    
    print(f"\nMonthly Data:")
    print(f"- Total product-month combinations: {len(monthly_agg)}")
    print(f"- Unique products: {monthly_agg['StockCode'].nunique()}")
    print(f"- Date range: {monthly_agg['YearMonth'].min()} to {monthly_agg['YearMonth'].max()}")
    print(f"- Records with sales: {(monthly_agg['Monthly_Quantity_Sold'] > 0).sum()}")
    print(f"- Records with zero sales: {(monthly_agg['Monthly_Quantity_Sold'] == 0).sum()}")
    print(f"- Total quantity sold: {monthly_agg['Monthly_Quantity_Sold'].sum():,.0f}")
    print(f"- Total revenue: £{monthly_agg['Monthly_Total_Price'].sum():,.2f}")
    
    print(f"\nWeekly Data:")
    print(f"- Total product-week combinations: {len(weekly_agg)}")
    print(f"- Unique products: {weekly_agg['StockCode'].nunique()}")
    print(f"- Date range: {weekly_agg['YearWeek'].min()} to {weekly_agg['YearWeek'].max()}")
    print(f"- Records with sales: {(weekly_agg['Weekly_Quantity_Sold'] > 0).sum()}")
    print(f"- Records with zero sales: {(weekly_agg['Weekly_Quantity_Sold'] == 0).sum()}")
    print(f"- Total quantity sold: {weekly_agg['Weekly_Quantity_Sold'].sum():,.0f}")
    print(f"- Total revenue: £{weekly_agg['Weekly_Total_Price'].sum():,.2f}")
    
    # Show distribution of per unit prices (excluding zeros)
    monthly_prices = monthly_agg[monthly_agg['Monthly_Per_Unit_Price'] > 0]['Monthly_Per_Unit_Price']
    weekly_prices = weekly_agg[weekly_agg['Weekly_Per_Unit_Price'] > 0]['Weekly_Per_Unit_Price']
    
    if len(monthly_prices) > 0:
        print(f"\nMonthly Per Unit Price Stats (excluding zeros):")
        print(f"- Average: £{monthly_prices.mean():.2f}")
        print(f"- Median: £{monthly_prices.median():.2f}")
        print(f"- Min: £{monthly_prices.min():.2f}")
        print(f"- Max: £{monthly_prices.max():.2f}")
    
    if len(weekly_prices) > 0:
        print(f"\nWeekly Per Unit Price Stats (excluding zeros):")
        print(f"- Average: £{weekly_prices.mean():.2f}")
        print(f"- Median: £{weekly_prices.median():.2f}")
        print(f"- Min: £{weekly_prices.min():.2f}")
        print(f"- Max: £{weekly_prices.max():.2f}")

# Implementing 

df = pd.read_csv('E:\sales_analysis\datasets\cleaned_data_with_filled_descriptions.csv')

monthly_data, weekly_data = create_aggregated_datasets(df)

analyze_aggregated_data(monthly_data, weekly_data)

monthly_data.to_csv('E:\sales_analysis\datasets\monthly_sales_aggregated.csv', index=False)
weekly_data.to_csv('E:\sales_analysis\datasets\weekly_sales_aggregated.csv', index=False)
# Out:
# <>:186: SyntaxWarning: invalid escape sequence '\s'
# <>:192: SyntaxWarning: invalid escape sequence '\s'
# <>:193: SyntaxWarning: invalid escape sequence '\s'
# <>:186: SyntaxWarning: invalid escape sequence '\s'
# <>:192: SyntaxWarning: invalid escape sequence '\s'
# <>:193: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\1866671278.py:186: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('E:\sales_analysis\datasets\cleaned_data_with_filled_descriptions.csv')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\1866671278.py:192: SyntaxWarning: invalid escape sequence '\s'
#   monthly_data.to_csv('E:\sales_analysis\datasets\monthly_sales_aggregated.csv', index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\1866671278.py:193: SyntaxWarning: invalid escape sequence '\s'
#   weekly_data.to_csv('E:\sales_analysis\datasets\weekly_sales_aggregated.csv', index=False)
# Processing 525096 transactions...
# Date range: 2009-12-01 07:45:00 to 2010-12-09 20:01:00
# Unique products: 4276
# Complete period range: 2009-12-01 to 2010-12-31
# Total months to cover: 13
# Total weeks to cover: 57
#
# Creating monthly aggregation...
# Monthly aggregation created: 55588 records
# Records with zero sales: 19363
#
# Creating weekly aggregation...
# Weekly aggregation created: 243732 records
# Records with zero sales: 140860
#
# === AGGREGATION ANALYSIS ===
#
# Monthly Data:
# - Total product-month combinations: 55588
# - Unique products: 4276
# - Date range: 2009-12 to 2010-12
# - Records with sales: 34756
# - Records with zero sales: 19363
# - Total quantity sold: 5,445,094
# - Total revenue: £9,539,484.63
#
# Weekly Data:
# - Total product-week combinations: 243732
# - Unique products: 4276
# - Date range: 2009-11-30/2009-12-06 to 2010-12-27/2011-01-02
# - Records with sales: 100123
# - Records with zero sales: 140860
# - Total quantity sold: 5,445,094
# - Total revenue: £9,539,484.63
#
# Monthly Per Unit Price Stats (excluding zeros):
# - Average: £3.83
# - Median: £2.14
# - Min: £0.00
# - Max: £945.79
#
# Weekly Per Unit Price Stats (excluding zeros):
# - Average: £3.64
# - Median: £2.10
# - Min: £0.00
# - Max: £945.79

# %%
# verifying number of datapoints

dfh = pd.read_csv('E:\sales_analysis\datasets\monthly_sales_aggregated.csv')

unique_products = dfh["StockCode"].unique()

print("TOTAL UNIQUE PRODUCTS :", len(unique_products))

print(55588/13)
# Out:
# TOTAL UNIQUE PRODUCTS : 4276
# 4276.0
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\3476065413.py:3: SyntaxWarning: invalid escape sequence '\s'
#   dfh = pd.read_csv('E:\sales_analysis\datasets\monthly_sales_aggregated.csv')

# %% [markdown]
# Objective 3 : Removing unnecessary datapoints from 'monthly_sales_aggregated.csv', 'weekly_sales_aggregated.csv', and 'product_sales_summary.csv'
#
# List of Unnecessary DataPoint (Entire Row) (these values are in Invoice column):
# * DOT
# * D
# * C2
# * BANK CHARGES
# * B
# * AMAZONFEE
# * ADJUST2
# * ADJUST
# * S
# * POST
# * M
# * m
# * gift_0001_10
# * gift_0001_20
# * gift_0001_30
# * gift_0001_40
# * gift_0001_50
# * gift_0001_60
# * gift_0001_70
# * gift_0001_80
#
# Method :
#
# -> Remove the entire row whose 'Invoice' value is from the list given above!

# %%
def remove_unnecessary_datapoints(file_paths, invoice_column='Invoice'):
    """
    Remove unnecessary datapoints from aggregated sales CSV files based on Invoice values.
    
    Parameters:
    file_paths (list): List of CSV file paths to clean
    stockcode_column (str): Name of the stock code column (default: 'StockCode')
    
    Returns:
    dict: Summary of cleaning results for each file
    """
    
    # List of unnecessary datapoint values to remove
    unnecessary_values = [
        'DOT', 'D', 'C2', 'BANK CHARGES', 'B', 'AMAZONFEE', 
        'ADJUST2', 'ADJUST', 'S', 'POST', 'M', 'm',
        'gift_0001_10', 'gift_0001_20', 'gift_0001_30', 'gift_0001_40',
        'gift_0001_50', 'gift_0001_60', 'gift_0001_70', 'gift_0001_80'
    ]
    
    print("=== REMOVING UNNECESSARY DATAPOINTS ===")
    print(f"Unnecessary values to remove: {unnecessary_values}")
    print(f"Files to process: {len(file_paths)}")
    
    results_summary = {}
    
    for file_path in file_paths:
        print(f"\n--- Processing: {file_path} ---")
        
        try:
            # Load the CSV file
            df = pd.read_csv(file_path)
            original_rows = len(df)
            
            print(f"Original rows: {original_rows}")
            
            # Check if Invoice column exists
            if invoice_column not in df.columns:
                print(f"WARNING: Column '{invoice_column}' not found in {file_path}")
                print(f"Available columns: {list(df.columns)}")
                results_summary[file_path] = {
                    'status': 'column_not_found',
                    'original_rows': original_rows,
                    'removed_rows': 0,
                    'final_rows': original_rows,
                    'available_columns': list(df.columns)
                }
                continue
            
            # Count occurrences of each unnecessary value before removal
            print("Unnecessary values found:")
            removal_counts = {}
            for value in unnecessary_values:
                count = (df[invoice_column] == value).sum()
                if count > 0:
                    removal_counts[value] = count
                    print(f"  {value}: {count} rows")
            
            if not removal_counts:
                print("  No unnecessary values found in this file")
            
            # Remove rows with unnecessary values
            mask = ~df[invoice_column].isin(unnecessary_values)
            df_cleaned = df[mask].copy()
            
            removed_rows = original_rows - len(df_cleaned)
            final_rows = len(df_cleaned)
            
            print(f"Rows removed: {removed_rows}")
            print(f"Final rows: {final_rows}")
            print(f"Percentage removed: {(removed_rows/original_rows)*100:.2f}%")
            
            # Save the cleaned file (backup original first)
            backup_path = file_path.replace('.csv', '_backup.csv')
            df.to_csv(backup_path, index=False)
            print(f"Original file backed up as: {backup_path}")
            
            # Save cleaned file
            df_cleaned.to_csv(file_path, index=False)
            print(f"Cleaned file saved: {file_path}")
            
            # Store results
            results_summary[file_path] = {
                'status': 'success',
                'original_rows': original_rows,
                'removed_rows': removed_rows,
                'final_rows': final_rows,
                'removal_details': removal_counts
            }
            
        except Exception as e:
            print(f"ERROR processing {file_path}: {e}")
            results_summary[file_path] = {
                'status': 'error',
                'error_message': str(e)
            }
    
    return results_summary

def clean_sales_files(monthly_file='datasets/monthly_sales_aggregated.csv', 
                     weekly_file='datasets/weekly_sales_aggregated.csv',
                     summary_file='datasets/product_sales_summary.csv',
                     stockcode_column='StockCode'):
    """
    Convenience function to clean the standard sales aggregation files.
    
    Parameters:
    monthly_file (str): Path to monthly sales file
    weekly_file (str): Path to weekly sales file  
    summary_file (str): Path to product sales summary file
    stockcode_column (str): Name of the stock code column
    
    Returns:
    dict: Cleaning results summary
    """
    
    file_paths = [monthly_file, weekly_file, summary_file]

    return remove_unnecessary_datapoints(file_paths, stockcode_column)

def print_cleaning_summary(results_summary):
    """
    Print a comprehensive summary of the cleaning results.
    
    Parameters:
    results_summary (dict): Results from remove_unnecessary_datapoints()
    """
    
    print("\n" + "="*60)
    print("CLEANING SUMMARY")
    print("="*60)
    
    total_original = 0
    total_removed = 0
    total_final = 0
    successful_files = 0
    
    for file_path, results in results_summary.items():
        print(f"\nFile: {file_path}")
        print(f"Status: {results['status']}")
        
        if results['status'] == 'success':
            successful_files += 1
            total_original += results['original_rows']
            total_removed += results['removed_rows']
            total_final += results['final_rows']
            
            print(f"  Original rows: {results['original_rows']:,}")
            print(f"  Removed rows: {results['removed_rows']:,}")
            print(f"  Final rows: {results['final_rows']:,}")
            print(f"  Removal rate: {(results['removed_rows']/results['original_rows'])*100:.2f}%")
            
            if results['removal_details']:
                print("  Removed values breakdown:")
                for value, count in results['removal_details'].items():
                    print(f"    {value}: {count:,} rows")
        
        elif results['status'] == 'file_not_found':
            print("  File not found - skipped")
        
        elif results['status'] == 'column_not_found':
            print(f"  Invoice column not found")
            print(f"  Available columns: {results.get('available_columns', [])}")
        
        elif results['status'] == 'error':
            print(f"  Error: {results['error_message']}")
    
    if successful_files > 0:
        print(f"\n" + "="*60)
        print("OVERALL SUMMARY")
        print("="*60)
        print(f"Files successfully processed: {successful_files}")
        print(f"Total original rows: {total_original:,}")
        print(f"Total removed rows: {total_removed:,}")
        print(f"Total final rows: {total_final:,}")
        print(f"Overall removal rate: {(total_removed/total_original)*100:.2f}%")

# Main execution
if __name__ == "__main__":
    
    
    print("Ready to clean sales aggregation files!")
    print("\nTo run the cleaning process, use one of these commands:")
    print("1. results = clean_sales_files()")
    print("2. print_cleaning_summary(results)")
    
    
    results = clean_sales_files()
    print_cleaning_summary(results)
# Out:
# Ready to clean sales aggregation files!
#
# To run the cleaning process, use one of these commands:
# 1. results = clean_sales_files()
# 2. print_cleaning_summary(results)
# === REMOVING UNNECESSARY DATAPOINTS ===
# Unnecessary values to remove: ['DOT', 'D', 'C2', 'BANK CHARGES', 'B', 'AMAZONFEE', 'ADJUST2', 'ADJUST', 'S', 'POST', 'M', 'm', 'gift_0001_10', 'gift_0001_20', 'gift_0001_30', 'gift_0001_40', 'gift_0001_50', 'gift_0001_60', 'gift_0001_70', 'gift_0001_80']
# Files to process: 3
#
# --- Processing: datasets/monthly_sales_aggregated.csv ---
# ERROR processing datasets/monthly_sales_aggregated.csv: [Errno 2] No such file or directory: 'datasets/monthly_sales_aggregated.csv'
#
# --- Processing: datasets/weekly_sales_aggregated.csv ---
# ERROR processing datasets/weekly_sales_aggregated.csv: [Errno 2] No such file or directory: 'datasets/weekly_sales_aggregated.csv'
#
# --- Processing: datasets/product_sales_summary.csv ---
# ERROR processing datasets/product_sales_summary.csv: [Errno 2] No such file or directory: 'datasets/product_sales_summary.csv'
#
# ============================================================
# CLEANING SUMMARY
# ============================================================
#
# File: datasets/monthly_sales_aggregated.csv
# Status: error
#   Error: [Errno 2] No such file or directory: 'datasets/monthly_sales_aggregated.csv'
#
# File: datasets/weekly_sales_aggregated.csv
# Status: error
#   Error: [Errno 2] No such file or directory: 'datasets/weekly_sales_aggregated.csv'
#
# File: datasets/product_sales_summary.csv
# Status: error
#   Error: [Errno 2] No such file or directory: 'datasets/product_sales_summary.csv'

# %%
# Number of unique customers

unique_customers = df["Customer ID"].unique()

print("TOTAL UNIQUE CUSTOMERS :", len(unique_customers))
# Out:
# TOTAL UNIQUE CUSTOMERS : 4384
